# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen, urlretrieve
import re
import os
import os.path
from os import listdir
from os.path import isfile, join
import zipfile
import pandas as pd

# %% [markdown]
# # Set the download folder

# %%
CURRENT_DIR = os.getcwd()
directory = CURRENT_DIR + "/" + "scraped_data"
if not os.path.exists(directory):
    os.makedirs(directory)

# %% [markdown]
# # Download all zip files in the link

# %%
url = "http://mis.nyiso.com/public/P-58Blist.htm"
html_page = urlopen(url).read()
soup = BeautifulSoup(html_page, "lxml")
for link in soup.findAll('a'):
    temp = link.get('href')
    if temp.endswith('.zip'):
        file_name = temp.replace("_csv.zip", "")
        file_name = temp.replace("csv/pal/", "")
        print(file_name)
        full_url = "http://mis.nyiso.com/public/"+temp
        filename = os.path.join(directory, file_name)
        print("Downloading {}...".format(filename) )
        urlretrieve(full_url, filename)
        print("Done.")

# %% [markdown]
# # Read and unzip the files

# %%
onlyfiles = [f for f in listdir(directory) if isfile(join(directory, f))]

# %%
unzip_folder = directory + "/" + "unzipped_data"
if not os.path.exists(unzip_folder):
    os.makedirs(unzip_folder)

# %%
for file in onlyfiles:
    path_to_zip_file = directory + "/" + file
    zip_ref = zipfile.ZipFile(path_to_zip_file, 'r')
    zip_ref.extractall(unzip_folder)
    zip_ref.close()

# %% [markdown]
# # Read each file, convert it to time series data

# %%
sample = pd.read_csv(r"C:\Users\sleeba\OneDrive\florian_steinke\new_york_energy_monitor\scraped_data\unzipped_data\20010526pal.csv",
                    header = 0)
print(sample.head())
# Out:
#             Time Stamp Time Zone    Name     PTID  Load
# 0  05/26/2001 00:00:00       EDT  CAPITL  61757.0   985
# 1  05/26/2001 00:00:00       EDT  CENTRL  61754.0  1461
# 2  05/26/2001 00:00:00       EDT  DUNWOD  61760.0   443
# 3  05/26/2001 00:00:00       EDT  GENESE  61753.0   830
# 4  05/26/2001 00:00:00       EDT  HUD VL  61758.0   970

# %%
modify_sample = sample[["Time Stamp", "Name", "Load"]]
print(modify_sample.head())
# Out:
#             Time Stamp    Name  Load
# 0  05/26/2001 00:00:00  CAPITL   985
# 1  05/26/2001 00:00:00  CENTRL  1461
# 2  05/26/2001 00:00:00  DUNWOD   443
# 3  05/26/2001 00:00:00  GENESE   830
# 4  05/26/2001 00:00:00  HUD VL   970

# %%
modify_sample = modify_sample.pivot(index='Time Stamp', columns='Name', values='Load').reset_index()
print(modify.head())
# Out:
# Name           Time Stamp  CAPITL  CENTRL  DUNWOD  GENESE  HUD VL  MHK VL  \
# 0     05/26/2001 00:00:00     985    1461     443     830     970     623
# 1     05/26/2001 00:00:50     995    1455     455     818     990     614
# 2     05/26/2001 00:05:20     980    1447     441     816     980     605
# 3     05/26/2001 00:06:50     947    1417     431     800     962     611
# 4     05/26/2001 00:11:50     946    1429     439     798     969     610
#
# Name  MILLWD  N.Y.C._LONGIL  NORTH  WEST
# 0        166           6217    659  1505
# 1        150           6174    636  1474
# 2        158           6158    649  1484
# 3        153           6140    646  1515
# 4        148           6100    647  1465

# %% [markdown]
# # Do this transformation to all the files in unzipped folder and merge to a single file

# %%
csv_files = [f for f in listdir(unzip_folder) if isfile(join(unzip_folder, f))]

# %%
len(csv_files)
# Out:
# 5802

# %%
final_df = pd.DataFrame()
for i, file in enumerate(csv_files):
    try:
        df = pd.read_csv(unzip_folder + "/" + file, header=0)
        df = df[["Time Stamp", "Name", "Load"]]
        df = df.pivot(index='Time Stamp', columns='Name', values='Load').reset_index()
        final_df = final_df.append(df, ignore_index=True)
        print("{} of {} is done".format(i,len(csv_files)))
    except:
        print(i)
        continue
# Out:
# 0 of 5802 is done
# 1 of 5802 is done
# 2 of 5802 is done
# 3 of 5802 is done
# 4 of 5802 is done
# 5 of 5802 is done
# 6 of 5802 is done
# 7 of 5802 is done
# 8 of 5802 is done
# 9 of 5802 is done
# 10 of 5802 is done
# 11 of 5802 is done
# 12 of 5802 is done
# 13 of 5802 is done
# 14 of 5802 is done
# 15 of 5802 is done
# 16 of 5802 is done
# 17 of 5802 is done
# 18 of 5802 is done
# 19 of 5802 is done
# 20 of 5802 is done
# 21 of 5802 is done
# 22 of 5802 is done
# 23 of 5802 is done
# 24 of 5802 is done
# 25 of 5802 is done
# 26 of 5802 is done
# 27 of 5802 is done
# 28 of 5802 is done
# 29 of 5802 is done
# 30 of 5802 is done
# 31 of 5802 is done
# 32 of 5802 is done
# 33 of 5802 is done
# 34 of 5802 is done
# 35 of 5802 is done
# 36 of 5802 is done
# 37 of 5802 is done
# 38 of 5802 is done
# 39 of 5802 is done
# 40 of 5802 is done
# 41 of 5802 is done
# 42 of 5802 is done
# 43 of 5802 is done
# 44 of 5802 is done
# 45 of 5802 is done
# 46 of 5802 is done
# 47 of 5802 is done
# 48 of 5802 is done
# 49 of 5802 is done
# 50 of 5802 is done
# 51 of 5802 is done
# 52 of 5802 is done
# 53 of 5802 is done
# 54 of 5802 is done
# 55 of 5802 is done
# 56 of 5802 is done
# 57 of 5802 is done
# 58 of 5802 is done
# 59 of 5802 is done
# 60 of 5802 is done
# 61 of 5802 is done
# 62 of 5802 is done
# 63 of 5802 is done
# 64 of 5802 is done
# 65 of 5802 is done
# 66 of 5802 is done
# 67 of 5802 is done
# 68 of 5802 is done
# 69 of 5802 is done
# 70 of 5802 is done
# 71 of 5802 is done
# 72 of 5802 is done
# 73 of 5802 is done
# 74 of 5802 is done
# 75 of 5802 is done
# 76 of 5802 is done
# 77 of 5802 is done
# 78 of 5802 is done
# 79 of 5802 is done
# 80 of 5802 is done
# 81 of 5802 is done
# 82 of 5802 is done
# 83 of 5802 is done
# 84 of 5802 is done
# 85 of 5802 is done
# 86 of 5802 is done
# 87 of 5802 is done
# 88 of 5802 is done
# 89 of 5802 is done
# 90 of 5802 is done
# 91 of 5802 is done
# 92 of 5802 is done
# 93 of 5802 is done
# 94 of 5802 is done
# 95 of 5802 is done
# 96 of 5802 is done
# 97 of 5802 is done
# 98 of 5802 is done
# 99 of 5802 is done
# 100 of 5802 is done
# 101 of 5802 is done
# 102 of 5802 is done
# 103 of 5802 is done
# 104 of 5802 is done
# 105 of 5802 is done
# 106 of 5802 is done
# 107 of 5802 is done
# 108 of 5802 is done
# 109 of 5802 is done
# 110 of 5802 is done
# 111 of 5802 is done
# 112 of 5802 is done
# 113 of 5802 is done
# 114 of 5802 is done
# 115 of 5802 is done
# 116 of 5802 is done
# 117 of 5802 is done
# 118 of 5802 is done
# 119 of 5802 is done
# 120 of 5802 is done
# 121 of 5802 is done
# 122 of 5802 is done
# 123 of 5802 is done
# 124 of 5802 is done
# 125 of 5802 is done
# 126 of 5802 is done
# 127 of 5802 is done
# 128 of 5802 is done
# 129 of 5802 is done
# 130 of 5802 is done
# 131 of 5802 is done
# 132 of 5802 is done
# 133 of 5802 is done
# 134 of 5802 is done
# 135 of 5802 is done
# 136 of 5802 is done
# 137 of 5802 is done
# 138 of 5802 is done
# 139 of 5802 is done
# 140 of 5802 is done
# 141 of 5802 is done
# 142 of 5802 is done
# 143 of 5802 is done
# 144 of 5802 is done
# 145 of 5802 is done
# 146 of 5802 is done
# 147 of 5802 is done
# 148 of 5802 is done
# 149 of 5802 is done
# 150 of 5802 is done
# 151 of 5802 is done
# 152 of 5802 is done
# 153 of 5802 is done
# 154 of 5802 is done
# 155
# 156 of 5802 is done
# 157 of 5802 is done
# 158 of 5802 is done
# 159 of 5802 is done
# 160 of 5802 is done
# 161 of 5802 is done
# 162 of 5802 is done
# 163 of 5802 is done
# 164 of 5802 is done
# 165 of 5802 is done
# 166 of 5802 is done
# 167 of 5802 is done
# 168 of 5802 is done
# 169 of 5802 is done
# 170 of 5802 is done
# 171 of 5802 is done
# 172 of 5802 is done
# 173 of 5802 is done
# 174 of 5802 is done
# 175 of 5802 is done
# 176 of 5802 is done
# 177 of 5802 is done
# 178 of 5802 is done
# 179 of 5802 is done
# 180 of 5802 is done
# 181 of 5802 is done
# 182 of 5802 is done
# 183 of 5802 is done
# 184 of 5802 is done
# 185 of 5802 is done
# 186 of 5802 is done
# 187 of 5802 is done
# 188 of 5802 is done
# 189 of 5802 is done
# 190 of 5802 is done
# 191 of 5802 is done
# 192 of 5802 is done
# 193 of 5802 is done
# 194 of 5802 is done
# 195 of 5802 is done
# 196 of 5802 is done
# 197 of 5802 is done
# 198 of 5802 is done
# 199 of 5802 is done
# 200 of 5802 is done
# 201 of 5802 is done
# 202 of 5802 is done
# 203 of 5802 is done
# 204 of 5802 is done
# 205 of 5802 is done
# 206 of 5802 is done
# 207 of 5802 is done
# 208 of 5802 is done
# 209 of 5802 is done
# 210 of 5802 is done
# 211 of 5802 is done
# 212 of 5802 is done
# 213 of 5802 is done
# 214 of 5802 is done
# 215 of 5802 is done
# 216 of 5802 is done
# 217 of 5802 is done
# 218 of 5802 is done
# 219 of 5802 is done
# 220 of 5802 is done
# 221 of 5802 is done
# 222 of 5802 is done
# 223 of 5802 is done
# 224 of 5802 is done
# 225 of 5802 is done
# 226 of 5802 is done
# 227 of 5802 is done
# 228 of 5802 is done
# 229 of 5802 is done
# 230 of 5802 is done
# 231 of 5802 is done
# 232 of 5802 is done
# 233 of 5802 is done
# 234 of 5802 is done
# 235 of 5802 is done
# 236 of 5802 is done
# 237 of 5802 is done
# 238 of 5802 is done
# 239 of 5802 is done
# 240 of 5802 is done
# 241 of 5802 is done
# 242 of 5802 is done
# 243 of 5802 is done
# 244 of 5802 is done
# 245 of 5802 is done
# 246 of 5802 is done
# 247 of 5802 is done
# 248 of 5802 is done
# 249 of 5802 is done
# 250 of 5802 is done
# 251
# 252 of 5802 is done
# 253 of 5802 is done
# 254 of 5802 is done
# 255 of 5802 is done
# 256 of 5802 is done
# 257 of 5802 is done
# 258 of 5802 is done
# 259 of 5802 is done
# 260 of 5802 is done
# 261 of 5802 is done
# 262 of 5802 is done
# 263 of 5802 is done
# 264 of 5802 is done
# 265 of 5802 is done
# 266 of 5802 is done
# 267 of 5802 is done
# 268 of 5802 is done
# 269 of 5802 is done
# 270 of 5802 is done
# 271 of 5802 is done
# 272 of 5802 is done
# 273 of 5802 is done
# 274 of 5802 is done
# 275 of 5802 is done
# 276 of 5802 is done
# 277 of 5802 is done
# 278 of 5802 is done
# 279 of 5802 is done
# 280 of 5802 is done
# 281 of 5802 is done
# 282 of 5802 is done
# 283 of 5802 is done
# 284 of 5802 is done
# 285 of 5802 is done
# 286 of 5802 is done
# 287 of 5802 is done
# 288 of 5802 is done
# 289 of 5802 is done
# 290 of 5802 is done
# 291 of 5802 is done
# 292 of 5802 is done
# 293 of 5802 is done
# 294 of 5802 is done
# 295 of 5802 is done
# 296 of 5802 is done
# 297 of 5802 is done
# 298 of 5802 is done
# 299 of 5802 is done
# 300 of 5802 is done
# 301 of 5802 is done
# 302 of 5802 is done
# 303 of 5802 is done
# 304 of 5802 is done
# 305 of 5802 is done
# 306 of 5802 is done
# 307 of 5802 is done
# 308 of 5802 is done
# 309 of 5802 is done
# 310 of 5802 is done
# 311 of 5802 is done
# 312 of 5802 is done
# 313 of 5802 is done
# 314 of 5802 is done
# 315 of 5802 is done
# 316 of 5802 is done
# 317 of 5802 is done
# 318 of 5802 is done
# 319 of 5802 is done
# 320 of 5802 is done
# 321 of 5802 is done
# 322 of 5802 is done
# 323 of 5802 is done
# 324 of 5802 is done
# 325 of 5802 is done
# 326 of 5802 is done
# 327 of 5802 is done
# 328
# 329 of 5802 is done
# 330 of 5802 is done
# 331 of 5802 is done
# 332 of 5802 is done
# 333 of 5802 is done
# 334 of 5802 is done
# 335 of 5802 is done
# 336 of 5802 is done
# 337 of 5802 is done
# 338 of 5802 is done
# 339 of 5802 is done
# 340 of 5802 is done
# 341 of 5802 is done
# 342 of 5802 is done
# 343 of 5802 is done
# 344 of 5802 is done
# 345 of 5802 is done
# 346 of 5802 is done
# 347 of 5802 is done
# 348 of 5802 is done
# 349 of 5802 is done
# 350 of 5802 is done
# 351 of 5802 is done
# 352 of 5802 is done
# 353 of 5802 is done
# 354 of 5802 is done
# 355 of 5802 is done
# 356 of 5802 is done
# 357 of 5802 is done
# 358 of 5802 is done
# 359 of 5802 is done
# 360 of 5802 is done
# 361 of 5802 is done
# 362 of 5802 is done
# 363 of 5802 is done
# 364 of 5802 is done
# 365 of 5802 is done
# 366 of 5802 is done
# 367 of 5802 is done
# 368 of 5802 is done
# 369 of 5802 is done
# 370 of 5802 is done
# 371 of 5802 is done
# 372 of 5802 is done
# 373 of 5802 is done
# 374 of 5802 is done
# 375 of 5802 is done
# 376 of 5802 is done
# 377 of 5802 is done
# 378 of 5802 is done
# 379 of 5802 is done
# 380 of 5802 is done
# 381 of 5802 is done
# 382 of 5802 is done
# 383 of 5802 is done
# 384 of 5802 is done
# 385 of 5802 is done
# 386 of 5802 is done
# 387 of 5802 is done
# 388 of 5802 is done
# 389 of 5802 is done
# 390 of 5802 is done
# 391 of 5802 is done
# 392 of 5802 is done
# 393 of 5802 is done
# 394 of 5802 is done
# 395 of 5802 is done
# 396 of 5802 is done
# 397 of 5802 is done
# 398 of 5802 is done
# 399 of 5802 is done
# 400 of 5802 is done
# 401 of 5802 is done
# 402 of 5802 is done
# 403 of 5802 is done
# 404 of 5802 is done
# 405 of 5802 is done
# 406 of 5802 is done
# 407 of 5802 is done
# 408 of 5802 is done
# 409 of 5802 is done
# 410 of 5802 is done
# 411 of 5802 is done
# 412 of 5802 is done
# 413 of 5802 is done
# 414 of 5802 is done
# 415 of 5802 is done
# 416 of 5802 is done
# 417 of 5802 is done
# 418 of 5802 is done
# 419 of 5802 is done
# 420 of 5802 is done
# 421 of 5802 is done
# 422 of 5802 is done
# 423 of 5802 is done
# 424 of 5802 is done
# 425 of 5802 is done
# 426 of 5802 is done
# 427 of 5802 is done
# 428 of 5802 is done
# 429 of 5802 is done
# 430 of 5802 is done
# 431 of 5802 is done
# 432 of 5802 is done
# 433 of 5802 is done
# 434 of 5802 is done
# 435 of 5802 is done
# 436 of 5802 is done
# 437 of 5802 is done
# 438 of 5802 is done
# 439 of 5802 is done
# 440 of 5802 is done
# 441 of 5802 is done
# 442 of 5802 is done
# 443 of 5802 is done
# 444 of 5802 is done
# 445 of 5802 is done
# 446 of 5802 is done
# 447 of 5802 is done
# 448 of 5802 is done
# 449 of 5802 is done
# 450 of 5802 is done
# 451 of 5802 is done
# 452 of 5802 is done
# 453 of 5802 is done
# 454 of 5802 is done
# 455 of 5802 is done
# 456 of 5802 is done
# 457 of 5802 is done
# 458 of 5802 is done
# 459 of 5802 is done
# 460 of 5802 is done
# 461 of 5802 is done
# 462 of 5802 is done
# 463 of 5802 is done
# 464 of 5802 is done
# 465 of 5802 is done
# 466 of 5802 is done
# 467 of 5802 is done
# 468 of 5802 is done
# 469 of 5802 is done
# 470 of 5802 is done
# 471 of 5802 is done
# 472 of 5802 is done
# 473 of 5802 is done
# 474 of 5802 is done
# 475 of 5802 is done
# 476 of 5802 is done
# 477 of 5802 is done
# 478 of 5802 is done
# 479 of 5802 is done
# 480 of 5802 is done
# 481 of 5802 is done
# 482 of 5802 is done
# 483 of 5802 is done
# 484 of 5802 is done
# 485 of 5802 is done
# 486 of 5802 is done
# 487 of 5802 is done
# 488 of 5802 is done
# 489 of 5802 is done
# 490 of 5802 is done
# 491 of 5802 is done
# 492 of 5802 is done
# 493 of 5802 is done
# 494 of 5802 is done
# 495 of 5802 is done
# 496 of 5802 is done
# 497 of 5802 is done
# 498 of 5802 is done
# 499 of 5802 is done
# 500 of 5802 is done
# 501 of 5802 is done
# 502 of 5802 is done
# 503 of 5802 is done
# 504 of 5802 is done
# 505 of 5802 is done
# 506 of 5802 is done
# 507 of 5802 is done
# 508 of 5802 is done
# 509 of 5802 is done
# 510 of 5802 is done
# 511 of 5802 is done
# 512 of 5802 is done
# 513 of 5802 is done
# 514 of 5802 is done
# 515 of 5802 is done
# 516 of 5802 is done
# 517 of 5802 is done
# 518 of 5802 is done
# 519
# 520 of 5802 is done
# 521 of 5802 is done
# 522 of 5802 is done
# 523 of 5802 is done
# 524 of 5802 is done
# 525 of 5802 is done
# 526 of 5802 is done
# 527 of 5802 is done
# 528 of 5802 is done
# 529 of 5802 is done
# 530 of 5802 is done
# 531 of 5802 is done
# 532 of 5802 is done
# 533 of 5802 is done
# 534 of 5802 is done
# 535 of 5802 is done
# 536 of 5802 is done
# 537 of 5802 is done
# 538 of 5802 is done
# 539 of 5802 is done
# 540 of 5802 is done
# 541 of 5802 is done
# 542 of 5802 is done
# 543 of 5802 is done
# 544 of 5802 is done
# 545 of 5802 is done
# 546 of 5802 is done
# 547 of 5802 is done
# 548 of 5802 is done
# 549 of 5802 is done
# 550 of 5802 is done
# 551 of 5802 is done
# 552 of 5802 is done
# 553 of 5802 is done
# 554 of 5802 is done
# 555 of 5802 is done
# 556 of 5802 is done
# 557 of 5802 is done
# 558 of 5802 is done
# 559 of 5802 is done
# 560 of 5802 is done
# 561 of 5802 is done
# 562 of 5802 is done
# 563 of 5802 is done
# 564 of 5802 is done
# 565 of 5802 is done
# 566 of 5802 is done
# 567 of 5802 is done
# 568 of 5802 is done
# 569 of 5802 is done
# 570 of 5802 is done
# 571 of 5802 is done
# 572 of 5802 is done
# 573 of 5802 is done
# 574 of 5802 is done
# 575 of 5802 is done
# 576 of 5802 is done
# 577 of 5802 is done
# 578 of 5802 is done
# 579 of 5802 is done
# 580 of 5802 is done
# 581 of 5802 is done
# 582 of 5802 is done
# 583 of 5802 is done
# 584 of 5802 is done
# 585 of 5802 is done
# 586 of 5802 is done
# 587 of 5802 is done
# 588 of 5802 is done
# 589 of 5802 is done
# 590 of 5802 is done
# 591 of 5802 is done
# 592 of 5802 is done
# 593 of 5802 is done
# 594 of 5802 is done
# 595 of 5802 is done
# 596 of 5802 is done
# 597 of 5802 is done
# 598 of 5802 is done
# 599 of 5802 is done
# 600 of 5802 is done
# 601 of 5802 is done
# 602 of 5802 is done
# 603 of 5802 is done
# 604 of 5802 is done
# 605 of 5802 is done
# 606 of 5802 is done
# 607 of 5802 is done
# 608 of 5802 is done
# 609 of 5802 is done
# 610 of 5802 is done
# 611 of 5802 is done
# 612 of 5802 is done
# 613 of 5802 is done
# 614 of 5802 is done
# 615 of 5802 is done
# 616 of 5802 is done
# 617 of 5802 is done
# 618 of 5802 is done
# 619 of 5802 is done
# 620 of 5802 is done
# 621 of 5802 is done
# 622 of 5802 is done
# 623 of 5802 is done
# 624 of 5802 is done
# 625 of 5802 is done
# 626 of 5802 is done
# 627 of 5802 is done
# 628 of 5802 is done
# 629 of 5802 is done
# 630 of 5802 is done
# 631 of 5802 is done
# 632 of 5802 is done
# 633 of 5802 is done
# 634 of 5802 is done
# 635 of 5802 is done
# 636 of 5802 is done
# 637 of 5802 is done
# 638 of 5802 is done
# 639 of 5802 is done
# 640 of 5802 is done
# 641 of 5802 is done
# 642 of 5802 is done
# 643 of 5802 is done
# 644 of 5802 is done
# 645 of 5802 is done
# 646 of 5802 is done
# 647 of 5802 is done
# 648 of 5802 is done
# 649 of 5802 is done
# 650 of 5802 is done
# 651 of 5802 is done
# 652 of 5802 is done
# 653 of 5802 is done
# 654 of 5802 is done
# 655 of 5802 is done
# 656 of 5802 is done
# 657 of 5802 is done
# 658 of 5802 is done
# 659 of 5802 is done
# 660 of 5802 is done
# 661 of 5802 is done
# 662 of 5802 is done
# 663 of 5802 is done
# 664 of 5802 is done
# 665 of 5802 is done
# 666 of 5802 is done
# 667 of 5802 is done
# 668 of 5802 is done
# 669 of 5802 is done
# 670 of 5802 is done
# 671 of 5802 is done
# 672 of 5802 is done
# 673 of 5802 is done
# 674 of 5802 is done
# 675 of 5802 is done
# 676 of 5802 is done
# 677 of 5802 is done
# 678 of 5802 is done
# 679 of 5802 is done
# 680 of 5802 is done
# 681 of 5802 is done
# 682 of 5802 is done
# 683 of 5802 is done
# 684 of 5802 is done
# 685 of 5802 is done
# 686 of 5802 is done
# 687 of 5802 is done
# 688 of 5802 is done
# 689 of 5802 is done
# 690 of 5802 is done
# 691 of 5802 is done
# 692 of 5802 is done
# 693 of 5802 is done
# 694 of 5802 is done
# 695 of 5802 is done
# 696 of 5802 is done
# 697 of 5802 is done
# 698 of 5802 is done
# 699 of 5802 is done
# 700 of 5802 is done
# 701 of 5802 is done
# 702 of 5802 is done
# 703 of 5802 is done
# 704 of 5802 is done
# 705 of 5802 is done
# 706 of 5802 is done
# 707 of 5802 is done
# 708 of 5802 is done
# 709 of 5802 is done
# 710 of 5802 is done
# 711 of 5802 is done
# 712 of 5802 is done
# 713 of 5802 is done
# 714 of 5802 is done
# 715 of 5802 is done
# 716 of 5802 is done
# 717 of 5802 is done
# 718 of 5802 is done
# 719 of 5802 is done
# 720 of 5802 is done
# 721 of 5802 is done
# 722 of 5802 is done
# 723 of 5802 is done
# 724 of 5802 is done
# 725 of 5802 is done
# 726 of 5802 is done
# 727 of 5802 is done
# 728 of 5802 is done
# 729 of 5802 is done
# 730 of 5802 is done
# 731 of 5802 is done
# 732 of 5802 is done
# 733 of 5802 is done
# 734 of 5802 is done
# 735 of 5802 is done
# 736 of 5802 is done
# 737 of 5802 is done
# 738 of 5802 is done
# 739 of 5802 is done
# 740 of 5802 is done
# 741 of 5802 is done
# 742 of 5802 is done
# 743 of 5802 is done
# 744 of 5802 is done
# 745 of 5802 is done
# 746 of 5802 is done
# 747 of 5802 is done
# 748 of 5802 is done
# 749 of 5802 is done
# 750 of 5802 is done
# 751 of 5802 is done
# 752 of 5802 is done
# 753 of 5802 is done
# 754 of 5802 is done
# 755 of 5802 is done
# 756 of 5802 is done
# 757 of 5802 is done
# 758 of 5802 is done
# 759 of 5802 is done
# 760 of 5802 is done
# 761 of 5802 is done
# 762 of 5802 is done
# 763 of 5802 is done
# 764 of 5802 is done
# 765 of 5802 is done
# 766 of 5802 is done
# 767 of 5802 is done
# 768 of 5802 is done
# 769 of 5802 is done
# 770 of 5802 is done
# 771 of 5802 is done
# 772 of 5802 is done
# 773 of 5802 is done
# 774 of 5802 is done
# 775 of 5802 is done
# 776 of 5802 is done
# 777 of 5802 is done
# 778 of 5802 is done
# 779 of 5802 is done
# 780 of 5802 is done
# 781 of 5802 is done
# 782 of 5802 is done
# 783 of 5802 is done
# 784 of 5802 is done
# 785 of 5802 is done
# 786 of 5802 is done
# 787 of 5802 is done
# 788 of 5802 is done
# 789 of 5802 is done
# 790 of 5802 is done
# 791 of 5802 is done
# 792 of 5802 is done
# 793 of 5802 is done
# 794 of 5802 is done
# 795 of 5802 is done
# 796 of 5802 is done
# 797 of 5802 is done
# 798 of 5802 is done
# 799 of 5802 is done
# 800 of 5802 is done
# 801 of 5802 is done
# 802 of 5802 is done
# 803 of 5802 is done
# 804 of 5802 is done
# 805 of 5802 is done
# 806 of 5802 is done
# 807 of 5802 is done
# 808 of 5802 is done
# 809 of 5802 is done
# 810 of 5802 is done
# 811 of 5802 is done
# 812 of 5802 is done
# 813 of 5802 is done
# 814 of 5802 is done
# 815 of 5802 is done
# 816 of 5802 is done
# 817 of 5802 is done
# 818 of 5802 is done
# 819 of 5802 is done
# 820 of 5802 is done
# 821 of 5802 is done
# 822 of 5802 is done
# 823 of 5802 is done
# 824 of 5802 is done
# 825 of 5802 is done
# 826 of 5802 is done
# 827 of 5802 is done
# 828 of 5802 is done
# 829 of 5802 is done
# 830 of 5802 is done
# 831 of 5802 is done
# 832 of 5802 is done
# 833 of 5802 is done
# 834 of 5802 is done
# 835 of 5802 is done
# 836 of 5802 is done
# 837 of 5802 is done
# 838 of 5802 is done
# 839 of 5802 is done
# 840 of 5802 is done
# 841 of 5802 is done
# 842 of 5802 is done
# 843 of 5802 is done
# 844 of 5802 is done
# 845 of 5802 is done
# 846 of 5802 is done
# 847 of 5802 is done
# 848 of 5802 is done
# 849 of 5802 is done
# 850 of 5802 is done
# 851 of 5802 is done
# 852 of 5802 is done
# 853 of 5802 is done
# 854 of 5802 is done
# 855 of 5802 is done
# 856 of 5802 is done
# 857 of 5802 is done
# 858 of 5802 is done
# 859 of 5802 is done
# 860 of 5802 is done
# 861 of 5802 is done
# 862 of 5802 is done
# 863 of 5802 is done
# 864 of 5802 is done
# 865 of 5802 is done
# 866 of 5802 is done
# 867 of 5802 is done
# 868 of 5802 is done
# 869 of 5802 is done
# 870 of 5802 is done
# 871 of 5802 is done
# 872 of 5802 is done
# 873 of 5802 is done
# 874 of 5802 is done
# 875 of 5802 is done
# 876 of 5802 is done
# 877 of 5802 is done
# 878 of 5802 is done
# 879 of 5802 is done
# 880 of 5802 is done
# 881 of 5802 is done
# 882 of 5802 is done
# 883
# 884 of 5802 is done
# 885 of 5802 is done
# 886 of 5802 is done
# 887 of 5802 is done
# 888 of 5802 is done
# 889 of 5802 is done
# 890 of 5802 is done
# 891 of 5802 is done
# 892 of 5802 is done
# 893 of 5802 is done
# 894 of 5802 is done
# 895 of 5802 is done
# 896 of 5802 is done
# 897 of 5802 is done
# 898 of 5802 is done
# 899 of 5802 is done
# 900 of 5802 is done
# 901 of 5802 is done
# 902 of 5802 is done
# 903 of 5802 is done
# 904 of 5802 is done
# 905 of 5802 is done
# 906 of 5802 is done
# 907 of 5802 is done
# 908 of 5802 is done
# 909 of 5802 is done
# 910 of 5802 is done
# 911 of 5802 is done
# 912 of 5802 is done
# 913 of 5802 is done
# 914 of 5802 is done
# 915 of 5802 is done
# 916 of 5802 is done
# 917 of 5802 is done
# 918 of 5802 is done
# 919 of 5802 is done
# 920 of 5802 is done
# 921 of 5802 is done
# 922 of 5802 is done
# 923 of 5802 is done
# 924 of 5802 is done
# 925 of 5802 is done
# 926 of 5802 is done
# 927 of 5802 is done
# 928 of 5802 is done
# 929 of 5802 is done
# 930 of 5802 is done
# 931 of 5802 is done
# 932 of 5802 is done
# 933 of 5802 is done
# 934 of 5802 is done
# 935 of 5802 is done
# 936 of 5802 is done
# 937 of 5802 is done
# 938 of 5802 is done
# 939 of 5802 is done
# 940 of 5802 is done
# 941 of 5802 is done
# 942 of 5802 is done
# 943 of 5802 is done
# 944 of 5802 is done
# 945 of 5802 is done
# 946 of 5802 is done
# 947 of 5802 is done
# 948 of 5802 is done
# 949 of 5802 is done
# 950 of 5802 is done
# 951 of 5802 is done
# 952 of 5802 is done
# 953 of 5802 is done
# 954 of 5802 is done
# 955 of 5802 is done
# 956 of 5802 is done
# 957 of 5802 is done
# 958 of 5802 is done
# 959 of 5802 is done
# 960 of 5802 is done
# 961 of 5802 is done
# 962 of 5802 is done
# 963 of 5802 is done
# 964 of 5802 is done
# 965 of 5802 is done
# 966 of 5802 is done
# 967 of 5802 is done
# 968 of 5802 is done
# 969 of 5802 is done
# 970 of 5802 is done
# 971 of 5802 is done
# 972 of 5802 is done
# 973 of 5802 is done
# 974 of 5802 is done
# 975 of 5802 is done
# 976 of 5802 is done
# 977 of 5802 is done
# 978 of 5802 is done
# 979 of 5802 is done
# 980 of 5802 is done
# 981 of 5802 is done
# 982 of 5802 is done
# 983 of 5802 is done
# 984 of 5802 is done
# 985 of 5802 is done
# 986 of 5802 is done
# 987 of 5802 is done
# 988 of 5802 is done
# 989 of 5802 is done
# 990 of 5802 is done
# 991 of 5802 is done
# 992 of 5802 is done
# 993 of 5802 is done
# 994 of 5802 is done
# 995 of 5802 is done
# 996 of 5802 is done
# 997 of 5802 is done
# 998 of 5802 is done
# 999 of 5802 is done
# 1000 of 5802 is done
# 1001 of 5802 is done
# 1002 of 5802 is done
# 1003 of 5802 is done
# 1004 of 5802 is done
# 1005 of 5802 is done
# 1006 of 5802 is done
# 1007 of 5802 is done
# 1008 of 5802 is done
# 1009 of 5802 is done
# 1010 of 5802 is done
# 1011 of 5802 is done
# 1012 of 5802 is done
# 1013 of 5802 is done
# 1014 of 5802 is done
# 1015 of 5802 is done
# 1016 of 5802 is done
# 1017 of 5802 is done
# 1018 of 5802 is done
# 1019 of 5802 is done
# 1020 of 5802 is done
# 1021 of 5802 is done
# 1022 of 5802 is done
# 1023 of 5802 is done
# 1024 of 5802 is done
# 1025 of 5802 is done
# 1026 of 5802 is done
# 1027 of 5802 is done
# 1028 of 5802 is done
# 1029 of 5802 is done
# 1030 of 5802 is done
# 1031 of 5802 is done
# 1032 of 5802 is done
# 1033 of 5802 is done
# 1034 of 5802 is done
# 1035 of 5802 is done
# 1036 of 5802 is done
# 1037 of 5802 is done
# 1038 of 5802 is done
# 1039 of 5802 is done
# 1040 of 5802 is done
# 1041 of 5802 is done
# 1042 of 5802 is done
# 1043 of 5802 is done
# 1044 of 5802 is done
# 1045 of 5802 is done
# 1046 of 5802 is done
# 1047 of 5802 is done
# 1048 of 5802 is done
# 1049 of 5802 is done
# 1050 of 5802 is done
# 1051 of 5802 is done
# 1052 of 5802 is done
# 1053 of 5802 is done
# 1054 of 5802 is done
# 1055 of 5802 is done
# 1056 of 5802 is done
# 1057 of 5802 is done
# 1058 of 5802 is done
# 1059 of 5802 is done
# 1060 of 5802 is done
# 1061 of 5802 is done
# 1062 of 5802 is done
# 1063 of 5802 is done
# 1064 of 5802 is done
# 1065 of 5802 is done
# 1066 of 5802 is done
# 1067 of 5802 is done
# 1068 of 5802 is done
# 1069 of 5802 is done
# 1070 of 5802 is done
# 1071 of 5802 is done
# 1072 of 5802 is done
# 1073 of 5802 is done
# 1074 of 5802 is done
# 1075 of 5802 is done
# 1076 of 5802 is done
# 1077 of 5802 is done
# 1078 of 5802 is done
# 1079 of 5802 is done
# 1080 of 5802 is done
# 1081 of 5802 is done
# 1082 of 5802 is done
# 1083 of 5802 is done
# 1084 of 5802 is done
# 1085 of 5802 is done
# 1086 of 5802 is done
# 1087 of 5802 is done
# 1088 of 5802 is done
# 1089 of 5802 is done
# 1090 of 5802 is done
# 1091 of 5802 is done
# 1092 of 5802 is done
# 1093 of 5802 is done
# 1094 of 5802 is done
# 1095 of 5802 is done
# 1096 of 5802 is done
# 1097 of 5802 is done
# 1098 of 5802 is done
# 1099 of 5802 is done
# 1100 of 5802 is done
# 1101 of 5802 is done
# 1102 of 5802 is done
# 1103 of 5802 is done
# 1104 of 5802 is done
# 1105 of 5802 is done
# 1106 of 5802 is done
# 1107 of 5802 is done
# 1108 of 5802 is done
# 1109 of 5802 is done
# 1110 of 5802 is done
# 1111 of 5802 is done
# 1112 of 5802 is done
# 1113 of 5802 is done
# 1114 of 5802 is done
# 1115 of 5802 is done
# 1116 of 5802 is done
# 1117 of 5802 is done
# 1118 of 5802 is done
# 1119 of 5802 is done
# 1120 of 5802 is done
# 1121 of 5802 is done
# 1122 of 5802 is done
# 1123 of 5802 is done
# 1124 of 5802 is done
# 1125 of 5802 is done
# 1126 of 5802 is done
# 1127 of 5802 is done
# 1128 of 5802 is done
# 1129 of 5802 is done
# 1130 of 5802 is done
# 1131 of 5802 is done
# 1132 of 5802 is done
# 1133 of 5802 is done
# 1134 of 5802 is done
# 1135 of 5802 is done
# 1136 of 5802 is done
# 1137 of 5802 is done
# 1138 of 5802 is done
# 1139 of 5802 is done
# 1140 of 5802 is done
# 1141 of 5802 is done
# 1142 of 5802 is done
# 1143 of 5802 is done
# 1144 of 5802 is done
# 1145 of 5802 is done
# 1146 of 5802 is done
# 1147 of 5802 is done
# 1148 of 5802 is done
# 1149 of 5802 is done
# 1150 of 5802 is done
# 1151 of 5802 is done
# 1152 of 5802 is done
# 1153 of 5802 is done
# 1154 of 5802 is done
# 1155 of 5802 is done
# 1156 of 5802 is done
# 1157 of 5802 is done
# 1158 of 5802 is done
# 1159 of 5802 is done
# 1160 of 5802 is done
# 1161 of 5802 is done
# 1162 of 5802 is done
# 1163 of 5802 is done
# 1164 of 5802 is done
# 1165 of 5802 is done
# 1166 of 5802 is done
# 1167 of 5802 is done
# 1168 of 5802 is done
# 1169 of 5802 is done
# 1170 of 5802 is done
# 1171 of 5802 is done
# 1172 of 5802 is done
# 1173 of 5802 is done
# 1174 of 5802 is done
# 1175 of 5802 is done
# 1176 of 5802 is done
# 1177 of 5802 is done
# 1178 of 5802 is done
# 1179 of 5802 is done
# 1180 of 5802 is done
# 1181 of 5802 is done
# 1182 of 5802 is done
# 1183 of 5802 is done
# 1184 of 5802 is done
# 1185 of 5802 is done
# 1186 of 5802 is done
# 1187 of 5802 is done
# 1188 of 5802 is done
# 1189 of 5802 is done
# 1190 of 5802 is done
# 1191 of 5802 is done
# 1192 of 5802 is done
# 1193 of 5802 is done
# 1194 of 5802 is done
# 1195 of 5802 is done
# 1196 of 5802 is done
# 1197 of 5802 is done
# 1198 of 5802 is done
# 1199 of 5802 is done
# 1200 of 5802 is done
# 1201 of 5802 is done
# 1202 of 5802 is done
# 1203 of 5802 is done
# 1204 of 5802 is done
# 1205 of 5802 is done
# 1206 of 5802 is done
# 1207 of 5802 is done
# 1208 of 5802 is done
# 1209 of 5802 is done
# 1210 of 5802 is done
# 1211 of 5802 is done
# 1212 of 5802 is done
# 1213 of 5802 is done
# 1214 of 5802 is done
# 1215 of 5802 is done
# 1216 of 5802 is done
# 1217 of 5802 is done
# 1218 of 5802 is done
# 1219 of 5802 is done
# 1220 of 5802 is done
# 1221 of 5802 is done
# 1222 of 5802 is done
# 1223 of 5802 is done
# 1224 of 5802 is done
# 1225 of 5802 is done
# 1226 of 5802 is done
# 1227 of 5802 is done
# 1228 of 5802 is done
# 1229 of 5802 is done
# 1230 of 5802 is done
# 1231 of 5802 is done
# 1232 of 5802 is done
# 1233 of 5802 is done
# 1234 of 5802 is done
# 1235 of 5802 is done
# 1236 of 5802 is done
# 1237 of 5802 is done
# 1238 of 5802 is done
# 1239 of 5802 is done
# 1240 of 5802 is done
# 1241 of 5802 is done
# 1242 of 5802 is done
# 1243 of 5802 is done
# 1244 of 5802 is done
# 1245 of 5802 is done
# 1246 of 5802 is done
# 1247 of 5802 is done
# 1248 of 5802 is done
# 1249 of 5802 is done
# 1250 of 5802 is done
# 1251 of 5802 is done
# 1252 of 5802 is done
# 1253 of 5802 is done
# 1254
# 1255 of 5802 is done
# 1256 of 5802 is done
# 1257 of 5802 is done
# 1258 of 5802 is done
# 1259 of 5802 is done
# 1260 of 5802 is done
# 1261 of 5802 is done
# 1262 of 5802 is done
# 1263 of 5802 is done
# 1264 of 5802 is done
# 1265 of 5802 is done
# 1266 of 5802 is done
# 1267 of 5802 is done
# 1268 of 5802 is done
# 1269 of 5802 is done
# 1270 of 5802 is done
# 1271 of 5802 is done
# 1272 of 5802 is done
# 1273 of 5802 is done
# 1274 of 5802 is done
# 1275 of 5802 is done
# 1276 of 5802 is done
# 1277 of 5802 is done
# 1278 of 5802 is done
# 1279 of 5802 is done
# 1280 of 5802 is done
# 1281 of 5802 is done
# 1282 of 5802 is done
# 1283 of 5802 is done
# 1284 of 5802 is done
# 1285 of 5802 is done
# 1286 of 5802 is done
# 1287 of 5802 is done
# 1288 of 5802 is done
# 1289 of 5802 is done
# 1290 of 5802 is done
# 1291 of 5802 is done
# 1292 of 5802 is done
# 1293 of 5802 is done
# 1294 of 5802 is done
# 1295 of 5802 is done
# 1296 of 5802 is done
# 1297 of 5802 is done
# 1298 of 5802 is done
# 1299 of 5802 is done
# 1300 of 5802 is done
# 1301 of 5802 is done
# 1302 of 5802 is done
# 1303 of 5802 is done
# 1304 of 5802 is done
# 1305 of 5802 is done
# 1306 of 5802 is done
# 1307 of 5802 is done
# 1308 of 5802 is done
# 1309 of 5802 is done
# 1310 of 5802 is done
# 1311 of 5802 is done
# 1312 of 5802 is done
# 1313 of 5802 is done
# 1314 of 5802 is done
# 1315 of 5802 is done
# 1316 of 5802 is done
# 1317 of 5802 is done
# 1318 of 5802 is done
# 1319 of 5802 is done
# 1320 of 5802 is done
# 1321 of 5802 is done
# 1322 of 5802 is done
# 1323 of 5802 is done
# 1324 of 5802 is done
# 1325 of 5802 is done
# 1326 of 5802 is done
# 1327 of 5802 is done
# 1328 of 5802 is done
# 1329 of 5802 is done
# 1330 of 5802 is done
# 1331 of 5802 is done
# 1332 of 5802 is done
# 1333 of 5802 is done
# 1334 of 5802 is done
# 1335 of 5802 is done
# 1336 of 5802 is done
# 1337 of 5802 is done
# 1338 of 5802 is done
# 1339 of 5802 is done
# 1340 of 5802 is done
# 1341 of 5802 is done
# 1342 of 5802 is done
# 1343 of 5802 is done
# 1344 of 5802 is done
# 1345 of 5802 is done
# 1346 of 5802 is done
# 1347 of 5802 is done
# 1348 of 5802 is done
# 1349 of 5802 is done
# 1350 of 5802 is done
# 1351 of 5802 is done
# 1352 of 5802 is done
# 1353 of 5802 is done
# 1354 of 5802 is done
# 1355 of 5802 is done
# 1356 of 5802 is done
# 1357 of 5802 is done
# 1358 of 5802 is done
# 1359 of 5802 is done
# 1360 of 5802 is done
# 1361 of 5802 is done
# 1362 of 5802 is done
# 1363 of 5802 is done
# 1364
# 1365 of 5802 is done
# 1366 of 5802 is done
# 1367 of 5802 is done
# 1368 of 5802 is done
# 1369 of 5802 is done
# 1370 of 5802 is done
# 1371 of 5802 is done
# 1372 of 5802 is done
# 1373 of 5802 is done
# 1374 of 5802 is done
# 1375 of 5802 is done
# 1376 of 5802 is done
# 1377 of 5802 is done
# 1378 of 5802 is done
# 1379 of 5802 is done
# 1380 of 5802 is done
# 1381 of 5802 is done
# 1382 of 5802 is done
# 1383 of 5802 is done
# 1384 of 5802 is done
# 1385 of 5802 is done
# 1386 of 5802 is done
# 1387 of 5802 is done
# 1388 of 5802 is done
# 1389 of 5802 is done
# 1390 of 5802 is done
# 1391 of 5802 is done
# 1392 of 5802 is done
# 1393 of 5802 is done
# 1394 of 5802 is done
# 1395 of 5802 is done
# 1396 of 5802 is done
# 1397 of 5802 is done
# 1398 of 5802 is done
# 1399
# 1400
# 1401 of 5802 is done
# 1402 of 5802 is done
# 1403 of 5802 is done
# 1404 of 5802 is done
# 1405 of 5802 is done
# 1406 of 5802 is done
# 1407 of 5802 is done
# 1408 of 5802 is done
# 1409 of 5802 is done
# 1410 of 5802 is done
# 1411 of 5802 is done
# 1412 of 5802 is done
# 1413 of 5802 is done
# 1414 of 5802 is done
# 1415 of 5802 is done
# 1416 of 5802 is done
# 1417 of 5802 is done
# 1418 of 5802 is done
# 1419 of 5802 is done
# 1420 of 5802 is done
# 1421 of 5802 is done
# 1422 of 5802 is done
# 1423 of 5802 is done
# 1424 of 5802 is done
# 1425 of 5802 is done
# 1426 of 5802 is done
# 1427 of 5802 is done
# 1428 of 5802 is done
# 1429 of 5802 is done
# 1430 of 5802 is done
# 1431 of 5802 is done
# 1432 of 5802 is done
# 1433 of 5802 is done
# 1434 of 5802 is done
# 1435 of 5802 is done
# 1436 of 5802 is done
# 1437 of 5802 is done
# 1438 of 5802 is done
# 1439 of 5802 is done
# 1440 of 5802 is done
# 1441 of 5802 is done
# 1442 of 5802 is done
# 1443 of 5802 is done
# 1444 of 5802 is done
# 1445 of 5802 is done
# 1446 of 5802 is done
# 1447 of 5802 is done
# 1448 of 5802 is done
# 1449 of 5802 is done
# 1450 of 5802 is done
# 1451 of 5802 is done
# 1452 of 5802 is done
# 1453 of 5802 is done
# 1454 of 5802 is done
# 1455 of 5802 is done
# 1456 of 5802 is done
# 1457 of 5802 is done
# 1458 of 5802 is done
# 1459 of 5802 is done
# 1460 of 5802 is done
# 1461 of 5802 is done
# 1462 of 5802 is done
# 1463 of 5802 is done
# 1464 of 5802 is done
# 1465 of 5802 is done
# 1466 of 5802 is done
# 1467 of 5802 is done
# 1468 of 5802 is done
# 1469 of 5802 is done
# 1470 of 5802 is done
# 1471 of 5802 is done
# 1472 of 5802 is done
# 1473 of 5802 is done
# 1474 of 5802 is done
# 1475 of 5802 is done
# 1476 of 5802 is done
# 1477 of 5802 is done
# 1478 of 5802 is done
# 1479 of 5802 is done
# 1480 of 5802 is done
# 1481 of 5802 is done
# 1482 of 5802 is done
# 1483 of 5802 is done
# 1484 of 5802 is done
# 1485 of 5802 is done
# 1486 of 5802 is done
# 1487 of 5802 is done
# 1488 of 5802 is done
# 1489 of 5802 is done
# 1490 of 5802 is done
# 1491 of 5802 is done
# 1492 of 5802 is done
# 1493 of 5802 is done
# 1494 of 5802 is done
# 1495 of 5802 is done
# 1496 of 5802 is done
# 1497
# 1498 of 5802 is done
# 1499 of 5802 is done
# 1500 of 5802 is done
# 1501 of 5802 is done
# 1502 of 5802 is done
# 1503 of 5802 is done
# 1504 of 5802 is done
# 1505 of 5802 is done
# 1506 of 5802 is done
# 1507 of 5802 is done
# 1508 of 5802 is done
# 1509 of 5802 is done
# 1510 of 5802 is done
# 1511 of 5802 is done
# 1512 of 5802 is done
# 1513 of 5802 is done
# 1514 of 5802 is done
# 1515 of 5802 is done
# 1516 of 5802 is done
# 1517 of 5802 is done
# 1518 of 5802 is done
# 1519 of 5802 is done
# 1520 of 5802 is done
# 1521 of 5802 is done
# 1522 of 5802 is done
# 1523 of 5802 is done
# 1524 of 5802 is done
# 1525 of 5802 is done
# 1526 of 5802 is done
# 1527 of 5802 is done
# 1528 of 5802 is done
# 1529 of 5802 is done
# 1530 of 5802 is done
# 1531 of 5802 is done
# 1532 of 5802 is done
# 1533 of 5802 is done
# 1534 of 5802 is done
# 1535 of 5802 is done
# 1536 of 5802 is done
# 1537 of 5802 is done
# 1538 of 5802 is done
# 1539 of 5802 is done
# 1540 of 5802 is done
# 1541 of 5802 is done
# 1542 of 5802 is done
# 1543 of 5802 is done
# 1544 of 5802 is done
# 1545 of 5802 is done
# 1546 of 5802 is done
# 1547 of 5802 is done
# 1548 of 5802 is done
# 1549 of 5802 is done
# 1550 of 5802 is done
# 1551 of 5802 is done
# 1552 of 5802 is done
# 1553 of 5802 is done
# 1554 of 5802 is done
# 1555 of 5802 is done
# 1556 of 5802 is done
# 1557 of 5802 is done
# 1558 of 5802 is done
# 1559 of 5802 is done
# 1560 of 5802 is done
# 1561 of 5802 is done
# 1562 of 5802 is done
# 1563 of 5802 is done
# 1564 of 5802 is done
# 1565 of 5802 is done
# 1566 of 5802 is done
# 1567 of 5802 is done
# 1568 of 5802 is done
# 1569 of 5802 is done
# 1570 of 5802 is done
# 1571 of 5802 is done
# 1572 of 5802 is done
# 1573 of 5802 is done
# 1574 of 5802 is done
# 1575 of 5802 is done
# 1576 of 5802 is done
# 1577 of 5802 is done
# 1578 of 5802 is done
# 1579 of 5802 is done
# 1580 of 5802 is done
# 1581 of 5802 is done
# 1582 of 5802 is done
# 1583 of 5802 is done
# 1584 of 5802 is done
# 1585 of 5802 is done
# 1586 of 5802 is done
# 1587 of 5802 is done
# 1588 of 5802 is done
# 1589 of 5802 is done
# 1590 of 5802 is done
# 1591 of 5802 is done
# 1592 of 5802 is done
# 1593 of 5802 is done
# 1594 of 5802 is done
# 1595 of 5802 is done
# 1596 of 5802 is done
# 1597 of 5802 is done
# 1598 of 5802 is done
# 1599 of 5802 is done
# 1600 of 5802 is done
# 1601 of 5802 is done
# 1602 of 5802 is done
# 1603 of 5802 is done
# 1604 of 5802 is done
# 1605 of 5802 is done
# 1606 of 5802 is done
# 1607 of 5802 is done
# 1608 of 5802 is done
# 1609 of 5802 is done
# 1610 of 5802 is done
# 1611 of 5802 is done
# 1612 of 5802 is done
# 1613 of 5802 is done
# 1614 of 5802 is done
# 1615 of 5802 is done
# 1616 of 5802 is done
# 1617 of 5802 is done
# 1618
# 1619 of 5802 is done
# 1620 of 5802 is done
# 1621 of 5802 is done
# 1622 of 5802 is done
# 1623 of 5802 is done
# 1624 of 5802 is done
# 1625 of 5802 is done
# 1626 of 5802 is done
# 1627 of 5802 is done
# 1628 of 5802 is done
# 1629 of 5802 is done
# 1630 of 5802 is done
# 1631 of 5802 is done
# 1632 of 5802 is done
# 1633 of 5802 is done
# 1634 of 5802 is done
# 1635 of 5802 is done
# 1636 of 5802 is done
# 1637 of 5802 is done
# 1638 of 5802 is done
# 1639 of 5802 is done
# 1640 of 5802 is done
# 1641 of 5802 is done
# 1642 of 5802 is done
# 1643 of 5802 is done
# 1644 of 5802 is done
# 1645 of 5802 is done
# 1646 of 5802 is done
# 1647 of 5802 is done
# 1648 of 5802 is done
# 1649 of 5802 is done
# 1650 of 5802 is done
# 1651 of 5802 is done
# 1652 of 5802 is done
# 1653 of 5802 is done
# 1654 of 5802 is done
# 1655 of 5802 is done
# 1656 of 5802 is done
# 1657 of 5802 is done
# 1658 of 5802 is done
# 1659 of 5802 is done
# 1660 of 5802 is done
# 1661 of 5802 is done
# 1662 of 5802 is done
# 1663 of 5802 is done
# 1664 of 5802 is done
# 1665 of 5802 is done
# 1666 of 5802 is done
# 1667 of 5802 is done
# 1668 of 5802 is done
# 1669 of 5802 is done
# 1670 of 5802 is done
# 1671 of 5802 is done
# 1672 of 5802 is done
# 1673 of 5802 is done
# 1674 of 5802 is done
# 1675 of 5802 is done
# 1676 of 5802 is done
# 1677 of 5802 is done
# 1678 of 5802 is done
# 1679 of 5802 is done
# 1680 of 5802 is done
# 1681 of 5802 is done
# 1682 of 5802 is done
# 1683 of 5802 is done
# 1684 of 5802 is done
# 1685 of 5802 is done
# 1686 of 5802 is done
# 1687 of 5802 is done
# 1688 of 5802 is done
# 1689 of 5802 is done
# 1690 of 5802 is done
# 1691 of 5802 is done
# 1692 of 5802 is done
# 1693 of 5802 is done
# 1694 of 5802 is done
# 1695 of 5802 is done
# 1696 of 5802 is done
# 1697 of 5802 is done
# 1698 of 5802 is done
# 1699 of 5802 is done
# 1700 of 5802 is done
# 1701 of 5802 is done
# 1702 of 5802 is done
# 1703 of 5802 is done
# 1704 of 5802 is done
# 1705 of 5802 is done
# 1706 of 5802 is done
# 1707 of 5802 is done
# 1708 of 5802 is done
# 1709 of 5802 is done
# 1710 of 5802 is done
# 1711 of 5802 is done
# 1712 of 5802 is done
# 1713 of 5802 is done
# 1714 of 5802 is done
# 1715 of 5802 is done
# 1716 of 5802 is done
# 1717 of 5802 is done
# 1718 of 5802 is done
# 1719 of 5802 is done
# 1720 of 5802 is done
# 1721 of 5802 is done
# 1722 of 5802 is done
# 1723 of 5802 is done
# 1724 of 5802 is done
# 1725 of 5802 is done
# 1726 of 5802 is done
# 1727 of 5802 is done
# 1728 of 5802 is done
# 1729 of 5802 is done
# 1730 of 5802 is done
# 1731 of 5802 is done
# 1732 of 5802 is done
# 1733 of 5802 is done
# 1734 of 5802 is done
# 1735 of 5802 is done
# 1736 of 5802 is done
# 1737 of 5802 is done
# 1738 of 5802 is done
# 1739 of 5802 is done
# 1740 of 5802 is done
# 1741 of 5802 is done
# 1742 of 5802 is done
# 1743 of 5802 is done
# 1744 of 5802 is done
# 1745 of 5802 is done
# 1746 of 5802 is done
# 1747 of 5802 is done
# 1748 of 5802 is done
# 1749 of 5802 is done
# 1750 of 5802 is done
# 1751 of 5802 is done
# 1752 of 5802 is done
# 1753 of 5802 is done
# 1754 of 5802 is done
# 1755 of 5802 is done
# 1756 of 5802 is done
# 1757 of 5802 is done
# 1758 of 5802 is done
# 1759 of 5802 is done
# 1760 of 5802 is done
# 1761 of 5802 is done
# 1762 of 5802 is done
# 1763 of 5802 is done
# 1764 of 5802 is done
# 1765 of 5802 is done
# 1766 of 5802 is done
# 1767 of 5802 is done
# 1768 of 5802 is done
# 1769 of 5802 is done
# 1770 of 5802 is done
# 1771 of 5802 is done
# 1772 of 5802 is done
# 1773 of 5802 is done
# 1774 of 5802 is done
# 1775 of 5802 is done
# 1776 of 5802 is done
# 1777 of 5802 is done
# 1778 of 5802 is done
# 1779 of 5802 is done
# 1780 of 5802 is done
# 1781 of 5802 is done
# 1782 of 5802 is done
# 1783 of 5802 is done
# 1784 of 5802 is done
# 1785 of 5802 is done
# 1786 of 5802 is done
# 1787 of 5802 is done
# 1788 of 5802 is done
# 1789 of 5802 is done
# 1790 of 5802 is done
# 1791 of 5802 is done
# 1792 of 5802 is done
# 1793 of 5802 is done
# 1794 of 5802 is done
# 1795 of 5802 is done
# 1796 of 5802 is done
# 1797 of 5802 is done
# 1798 of 5802 is done
# 1799 of 5802 is done
# 1800 of 5802 is done
# 1801 of 5802 is done
# 1802 of 5802 is done
# 1803 of 5802 is done
# 1804 of 5802 is done
# 1805 of 5802 is done
# 1806 of 5802 is done
# 1807 of 5802 is done
# 1808 of 5802 is done
# 1809 of 5802 is done
# 1810 of 5802 is done
# 1811 of 5802 is done
# 1812 of 5802 is done
# 1813 of 5802 is done
# 1814 of 5802 is done
# 1815 of 5802 is done
# 1816 of 5802 is done
# 1817 of 5802 is done
# 1818 of 5802 is done
# 1819 of 5802 is done
# 1820 of 5802 is done
# 1821 of 5802 is done
# 1822 of 5802 is done
# 1823 of 5802 is done
# 1824 of 5802 is done
# 1825 of 5802 is done
# 1826 of 5802 is done
# 1827 of 5802 is done
# 1828 of 5802 is done
# 1829 of 5802 is done
# 1830 of 5802 is done
# 1831 of 5802 is done
# 1832 of 5802 is done
# 1833 of 5802 is done
# 1834 of 5802 is done
# 1835 of 5802 is done
# 1836 of 5802 is done
# 1837 of 5802 is done
# 1838 of 5802 is done
# 1839 of 5802 is done
# 1840 of 5802 is done
# 1841 of 5802 is done
# 1842 of 5802 is done
# 1843 of 5802 is done
# 1844 of 5802 is done
# 1845 of 5802 is done
# 1846 of 5802 is done
# 1847 of 5802 is done
# 1848 of 5802 is done
# 1849 of 5802 is done
# 1850 of 5802 is done
# 1851 of 5802 is done
# 1852 of 5802 is done
# 1853 of 5802 is done
# 1854 of 5802 is done
# 1855 of 5802 is done
# 1856 of 5802 is done
# 1857 of 5802 is done
# 1858 of 5802 is done
# 1859 of 5802 is done
# 1860 of 5802 is done
# 1861 of 5802 is done
# 1862 of 5802 is done
# 1863 of 5802 is done
# 1864 of 5802 is done
# 1865 of 5802 is done
# 1866 of 5802 is done
# 1867 of 5802 is done
# 1868 of 5802 is done
# 1869 of 5802 is done
# 1870 of 5802 is done
# 1871 of 5802 is done
# 1872 of 5802 is done
# 1873 of 5802 is done
# 1874 of 5802 is done
# 1875 of 5802 is done
# 1876 of 5802 is done
# 1877 of 5802 is done
# 1878 of 5802 is done
# 1879 of 5802 is done
# 1880 of 5802 is done
# 1881 of 5802 is done
# 1882 of 5802 is done
# 1883 of 5802 is done
# 1884 of 5802 is done
# 1885 of 5802 is done
# 1886 of 5802 is done
# 1887 of 5802 is done
# 1888 of 5802 is done
# 1889 of 5802 is done
# 1890 of 5802 is done
# 1891 of 5802 is done
# 1892 of 5802 is done
# 1893 of 5802 is done
# 1894 of 5802 is done
# 1895 of 5802 is done
# 1896 of 5802 is done
# 1897 of 5802 is done
# 1898 of 5802 is done
# 1899 of 5802 is done
# 1900 of 5802 is done
# 1901 of 5802 is done
# 1902 of 5802 is done
# 1903 of 5802 is done
# 1904 of 5802 is done
# 1905 of 5802 is done
# 1906 of 5802 is done
# 1907 of 5802 is done
# 1908 of 5802 is done
# 1909 of 5802 is done
# 1910 of 5802 is done
# 1911 of 5802 is done
# 1912 of 5802 is done
# 1913 of 5802 is done
# 1914 of 5802 is done
# 1915 of 5802 is done
# 1916 of 5802 is done
# 1917 of 5802 is done
# 1918 of 5802 is done
# 1919 of 5802 is done
# 1920 of 5802 is done
# 1921 of 5802 is done
# 1922 of 5802 is done
# 1923 of 5802 is done
# 1924 of 5802 is done
# 1925 of 5802 is done
# 1926 of 5802 is done
# 1927 of 5802 is done
# 1928 of 5802 is done
# 1929 of 5802 is done
# 1930 of 5802 is done
# 1931 of 5802 is done
# 1932 of 5802 is done
# 1933 of 5802 is done
# 1934 of 5802 is done
# 1935 of 5802 is done
# 1936 of 5802 is done
# 1937 of 5802 is done
# 1938 of 5802 is done
# 1939 of 5802 is done
# 1940 of 5802 is done
# 1941 of 5802 is done
# 1942 of 5802 is done
# 1943 of 5802 is done
# 1944 of 5802 is done
# 1945 of 5802 is done
# 1946 of 5802 is done
# 1947 of 5802 is done
# 1948 of 5802 is done
# 1949 of 5802 is done
# 1950 of 5802 is done
# 1951 of 5802 is done
# 1952 of 5802 is done
# 1953 of 5802 is done
# 1954 of 5802 is done
# 1955 of 5802 is done
# 1956 of 5802 is done
# 1957 of 5802 is done
# 1958 of 5802 is done
# 1959 of 5802 is done
# 1960 of 5802 is done
# 1961 of 5802 is done
# 1962 of 5802 is done
# 1963 of 5802 is done
# 1964 of 5802 is done
# 1965 of 5802 is done
# 1966 of 5802 is done
# 1967 of 5802 is done
# 1968 of 5802 is done
# 1969 of 5802 is done
# 1970 of 5802 is done
# 1971 of 5802 is done
# 1972 of 5802 is done
# 1973 of 5802 is done
# 1974 of 5802 is done
# 1975 of 5802 is done
# 1976 of 5802 is done
# 1977 of 5802 is done
# 1978 of 5802 is done
# 1979 of 5802 is done
# 1980 of 5802 is done
# 1981 of 5802 is done
# 1982
# 1983 of 5802 is done
# 1984 of 5802 is done
# 1985 of 5802 is done
# 1986 of 5802 is done
# 1987 of 5802 is done
# 1988 of 5802 is done
# 1989 of 5802 is done
# 1990 of 5802 is done
# 1991 of 5802 is done
# 1992 of 5802 is done
# 1993 of 5802 is done
# 1994 of 5802 is done
# 1995 of 5802 is done
# 1996 of 5802 is done
# 1997 of 5802 is done
# 1998 of 5802 is done
# 1999 of 5802 is done
# 2000 of 5802 is done
# 2001 of 5802 is done
# 2002 of 5802 is done
# 2003 of 5802 is done
# 2004 of 5802 is done
# 2005 of 5802 is done
# 2006 of 5802 is done
# 2007 of 5802 is done
# 2008 of 5802 is done
# 2009 of 5802 is done
# 2010 of 5802 is done
# 2011 of 5802 is done
# 2012 of 5802 is done
# 2013 of 5802 is done
# 2014 of 5802 is done
# 2015 of 5802 is done
# 2016 of 5802 is done
# 2017 of 5802 is done
# 2018 of 5802 is done
# 2019 of 5802 is done
# 2020 of 5802 is done
# 2021 of 5802 is done
# 2022 of 5802 is done
# 2023 of 5802 is done
# 2024 of 5802 is done
# 2025 of 5802 is done
# 2026 of 5802 is done
# 2027 of 5802 is done
# 2028 of 5802 is done
# 2029 of 5802 is done
# 2030 of 5802 is done
# 2031 of 5802 is done
# 2032 of 5802 is done
# 2033 of 5802 is done
# 2034 of 5802 is done
# 2035 of 5802 is done
# 2036 of 5802 is done
# 2037 of 5802 is done
# 2038 of 5802 is done
# 2039 of 5802 is done
# 2040 of 5802 is done
# 2041 of 5802 is done
# 2042 of 5802 is done
# 2043 of 5802 is done
# 2044 of 5802 is done
# 2045 of 5802 is done
# 2046 of 5802 is done
# 2047 of 5802 is done
# 2048 of 5802 is done
# 2049 of 5802 is done
# 2050 of 5802 is done
# 2051 of 5802 is done
# 2052 of 5802 is done
# 2053 of 5802 is done
# 2054 of 5802 is done
# 2055 of 5802 is done
# 2056 of 5802 is done
# 2057 of 5802 is done
# 2058 of 5802 is done
# 2059 of 5802 is done
# 2060 of 5802 is done
# 2061 of 5802 is done
# 2062 of 5802 is done
# 2063 of 5802 is done
# 2064 of 5802 is done
# 2065 of 5802 is done
# 2066 of 5802 is done
# 2067 of 5802 is done
# 2068 of 5802 is done
# 2069 of 5802 is done
# 2070 of 5802 is done
# 2071 of 5802 is done
# 2072 of 5802 is done
# 2073 of 5802 is done
# 2074 of 5802 is done
# 2075 of 5802 is done
# 2076 of 5802 is done
# 2077 of 5802 is done
# 2078 of 5802 is done
# 2079 of 5802 is done
# 2080 of 5802 is done
# 2081 of 5802 is done
# 2082 of 5802 is done
# 2083 of 5802 is done
# 2084 of 5802 is done
# 2085 of 5802 is done
# 2086 of 5802 is done
# 2087 of 5802 is done
# 2088 of 5802 is done
# 2089 of 5802 is done
# 2090 of 5802 is done
# 2091 of 5802 is done
# 2092 of 5802 is done
# 2093 of 5802 is done
# 2094 of 5802 is done
# 2095 of 5802 is done
# 2096 of 5802 is done
# 2097 of 5802 is done
# 2098 of 5802 is done
# 2099 of 5802 is done
# 2100 of 5802 is done
# 2101 of 5802 is done
# 2102 of 5802 is done
# 2103 of 5802 is done
# 2104 of 5802 is done
# 2105 of 5802 is done
# 2106 of 5802 is done
# 2107 of 5802 is done
# 2108 of 5802 is done
# 2109 of 5802 is done
# 2110 of 5802 is done
# 2111 of 5802 is done
# 2112 of 5802 is done
# 2113 of 5802 is done
# 2114 of 5802 is done
# 2115 of 5802 is done
# 2116 of 5802 is done
# 2117 of 5802 is done
# 2118 of 5802 is done
# 2119 of 5802 is done
# 2120 of 5802 is done
# 2121 of 5802 is done
# 2122 of 5802 is done
# 2123 of 5802 is done
# 2124 of 5802 is done
# 2125 of 5802 is done
# 2126 of 5802 is done
# 2127 of 5802 is done
# 2128 of 5802 is done
# 2129 of 5802 is done
# 2130 of 5802 is done
# 2131 of 5802 is done
# 2132 of 5802 is done
# 2133 of 5802 is done
# 2134 of 5802 is done
# 2135 of 5802 is done
# 2136 of 5802 is done
# 2137 of 5802 is done
# 2138 of 5802 is done
# 2139 of 5802 is done
# 2140 of 5802 is done
# 2141 of 5802 is done
# 2142 of 5802 is done
# 2143 of 5802 is done
# 2144 of 5802 is done
# 2145 of 5802 is done
# 2146 of 5802 is done
# 2147 of 5802 is done
# 2148 of 5802 is done
# 2149 of 5802 is done
# 2150 of 5802 is done
# 2151 of 5802 is done
# 2152 of 5802 is done
# 2153 of 5802 is done
# 2154 of 5802 is done
# 2155 of 5802 is done
# 2156 of 5802 is done
# 2157 of 5802 is done
# 2158 of 5802 is done
# 2159 of 5802 is done
# 2160 of 5802 is done
# 2161 of 5802 is done
# 2162 of 5802 is done
# 2163 of 5802 is done
# 2164 of 5802 is done
# 2165 of 5802 is done
# 2166 of 5802 is done
# 2167 of 5802 is done
# 2168 of 5802 is done
# 2169 of 5802 is done
# 2170 of 5802 is done
# 2171 of 5802 is done
# 2172 of 5802 is done
# 2173 of 5802 is done
# 2174 of 5802 is done
# 2175 of 5802 is done
# 2176 of 5802 is done
# 2177 of 5802 is done
# 2178 of 5802 is done
# 2179 of 5802 is done
# 2180 of 5802 is done
# 2181 of 5802 is done
# 2182 of 5802 is done
# 2183 of 5802 is done
# 2184 of 5802 is done
# 2185 of 5802 is done
# 2186 of 5802 is done
# 2187 of 5802 is done
# 2188 of 5802 is done
# 2189 of 5802 is done
# 2190 of 5802 is done
# 2191 of 5802 is done
# 2192 of 5802 is done
# 2193 of 5802 is done
# 2194 of 5802 is done
# 2195 of 5802 is done
# 2196 of 5802 is done
# 2197 of 5802 is done
# 2198 of 5802 is done
# 2199 of 5802 is done
# 2200 of 5802 is done
# 2201 of 5802 is done
# 2202 of 5802 is done
# 2203 of 5802 is done
# 2204 of 5802 is done
# 2205 of 5802 is done
# 2206 of 5802 is done
# 2207 of 5802 is done
# 2208 of 5802 is done
# 2209 of 5802 is done
# 2210 of 5802 is done
# 2211 of 5802 is done
# 2212 of 5802 is done
# 2213 of 5802 is done
# 2214 of 5802 is done
# 2215 of 5802 is done
# 2216 of 5802 is done
# 2217 of 5802 is done
# 2218 of 5802 is done
# 2219 of 5802 is done
# 2220 of 5802 is done
# 2221 of 5802 is done
# 2222 of 5802 is done
# 2223 of 5802 is done
# 2224 of 5802 is done
# 2225 of 5802 is done
# 2226 of 5802 is done
# 2227 of 5802 is done
# 2228 of 5802 is done
# 2229 of 5802 is done
# 2230 of 5802 is done
# 2231 of 5802 is done
# 2232 of 5802 is done
# 2233 of 5802 is done
# 2234 of 5802 is done
# 2235 of 5802 is done
# 2236 of 5802 is done
# 2237 of 5802 is done
# 2238 of 5802 is done
# 2239 of 5802 is done
# 2240 of 5802 is done
# 2241 of 5802 is done
# 2242 of 5802 is done
# 2243 of 5802 is done
# 2244 of 5802 is done
# 2245 of 5802 is done
# 2246 of 5802 is done
# 2247 of 5802 is done
# 2248 of 5802 is done
# 2249 of 5802 is done
# 2250 of 5802 is done
# 2251 of 5802 is done
# 2252 of 5802 is done
# 2253 of 5802 is done
# 2254 of 5802 is done
# 2255 of 5802 is done
# 2256 of 5802 is done
# 2257 of 5802 is done
# 2258 of 5802 is done
# 2259 of 5802 is done
# 2260 of 5802 is done
# 2261 of 5802 is done
# 2262 of 5802 is done
# 2263 of 5802 is done
# 2264 of 5802 is done
# 2265 of 5802 is done
# 2266 of 5802 is done
# 2267 of 5802 is done
# 2268 of 5802 is done
# 2269 of 5802 is done
# 2270 of 5802 is done
# 2271 of 5802 is done
# 2272 of 5802 is done
# 2273 of 5802 is done
# 2274 of 5802 is done
# 2275 of 5802 is done
# 2276 of 5802 is done
# 2277 of 5802 is done
# 2278 of 5802 is done
# 2279 of 5802 is done
# 2280 of 5802 is done
# 2281 of 5802 is done
# 2282 of 5802 is done
# 2283 of 5802 is done
# 2284 of 5802 is done
# 2285 of 5802 is done
# 2286 of 5802 is done
# 2287 of 5802 is done
# 2288 of 5802 is done
# 2289 of 5802 is done
# 2290 of 5802 is done
# 2291 of 5802 is done
# 2292 of 5802 is done
# 2293 of 5802 is done
# 2294 of 5802 is done
# 2295 of 5802 is done
# 2296 of 5802 is done
# 2297 of 5802 is done
# 2298 of 5802 is done
# 2299 of 5802 is done
# 2300 of 5802 is done
# 2301 of 5802 is done
# 2302 of 5802 is done
# 2303 of 5802 is done
# 2304 of 5802 is done
# 2305 of 5802 is done
# 2306 of 5802 is done
# 2307 of 5802 is done
# 2308 of 5802 is done
# 2309 of 5802 is done
# 2310 of 5802 is done
# 2311 of 5802 is done
# 2312 of 5802 is done
# 2313 of 5802 is done
# 2314 of 5802 is done
# 2315 of 5802 is done
# 2316 of 5802 is done
# 2317 of 5802 is done
# 2318 of 5802 is done
# 2319 of 5802 is done
# 2320 of 5802 is done
# 2321 of 5802 is done
# 2322 of 5802 is done
# 2323 of 5802 is done
# 2324 of 5802 is done
# 2325 of 5802 is done
# 2326 of 5802 is done
# 2327 of 5802 is done
# 2328 of 5802 is done
# 2329 of 5802 is done
# 2330 of 5802 is done
# 2331 of 5802 is done
# 2332 of 5802 is done
# 2333 of 5802 is done
# 2334 of 5802 is done
# 2335 of 5802 is done
# 2336 of 5802 is done
# 2337 of 5802 is done
# 2338 of 5802 is done
# 2339 of 5802 is done
# 2340 of 5802 is done
# 2341 of 5802 is done
# 2342 of 5802 is done
# 2343 of 5802 is done
# 2344 of 5802 is done
# 2345 of 5802 is done
# 2346 of 5802 is done
# ...
# 5039 of 5802 is done
# 5040 of 5802 is done
# 5041 of 5802 is done
# 5042 of 5802 is done
# 5043 of 5802 is done
# 5044 of 5802 is done
# 5045 of 5802 is done
# 5046 of 5802 is done
# 5047 of 5802 is done
# 5048 of 5802 is done
# 5049 of 5802 is done
# 5050 of 5802 is done
# 5051 of 5802 is done
# 5052 of 5802 is done
# 5053 of 5802 is done
# 5054 of 5802 is done
# 5055 of 5802 is done
# 5056 of 5802 is done
# 5057 of 5802 is done
# 5058 of 5802 is done
# 5059 of 5802 is done
# 5060 of 5802 is done
# 5061 of 5802 is done
# 5062 of 5802 is done
# 5063 of 5802 is done
# 5064 of 5802 is done
# 5065 of 5802 is done
# 5066 of 5802 is done
# 5067 of 5802 is done
# 5068 of 5802 is done
# 5069 of 5802 is done
# 5070 of 5802 is done
# 5071 of 5802 is done
# 5072 of 5802 is done
# 5073 of 5802 is done
# 5074 of 5802 is done
# 5075 of 5802 is done
# 5076 of 5802 is done
# 5077 of 5802 is done
# 5078 of 5802 is done
# 5079 of 5802 is done
# 5080 of 5802 is done
# 5081 of 5802 is done
# 5082 of 5802 is done
# 5083 of 5802 is done
# 5084 of 5802 is done
# 5085 of 5802 is done
# 5086 of 5802 is done
# 5087 of 5802 is done
# 5088 of 5802 is done
# 5089 of 5802 is done
# 5090 of 5802 is done
# 5091 of 5802 is done
# 5092 of 5802 is done
# 5093 of 5802 is done
# 5094 of 5802 is done
# 5095 of 5802 is done
# 5096 of 5802 is done
# 5097 of 5802 is done
# 5098 of 5802 is done
# 5099 of 5802 is done
# 5100 of 5802 is done
# 5101 of 5802 is done
# 5102 of 5802 is done
# 5103 of 5802 is done
# 5104 of 5802 is done
# 5105 of 5802 is done
# 5106 of 5802 is done
# 5107 of 5802 is done
# 5108 of 5802 is done
# 5109 of 5802 is done
# 5110 of 5802 is done
# 5111 of 5802 is done
# 5112 of 5802 is done
# 5113 of 5802 is done
# 5114 of 5802 is done
# 5115 of 5802 is done
# 5116 of 5802 is done
# 5117 of 5802 is done
# 5118 of 5802 is done
# 5119 of 5802 is done
# 5120 of 5802 is done
# 5121 of 5802 is done
# 5122 of 5802 is done
# 5123 of 5802 is done
# 5124 of 5802 is done
# 5125 of 5802 is done
# 5126 of 5802 is done
# 5127 of 5802 is done
# 5128 of 5802 is done
# 5129 of 5802 is done
# 5130 of 5802 is done
# 5131 of 5802 is done
# 5132 of 5802 is done
# 5133 of 5802 is done
# 5134 of 5802 is done
# 5135 of 5802 is done
# 5136 of 5802 is done
# 5137 of 5802 is done
# 5138 of 5802 is done
# 5139 of 5802 is done
# 5140 of 5802 is done
# 5141 of 5802 is done
# 5142 of 5802 is done
# 5143 of 5802 is done
# 5144 of 5802 is done
# 5145 of 5802 is done
# 5146 of 5802 is done
# 5147 of 5802 is done
# 5148 of 5802 is done
# 5149 of 5802 is done
# 5150 of 5802 is done
# 5151 of 5802 is done
# 5152 of 5802 is done
# 5153 of 5802 is done
# 5154 of 5802 is done
# 5155 of 5802 is done
# 5156 of 5802 is done
# 5157 of 5802 is done
# 5158 of 5802 is done
# 5159 of 5802 is done
# 5160 of 5802 is done
# 5161 of 5802 is done
# 5162 of 5802 is done
# 5163 of 5802 is done
# 5164 of 5802 is done
# 5165 of 5802 is done
# 5166 of 5802 is done
# 5167 of 5802 is done
# 5168 of 5802 is done
# 5169 of 5802 is done
# 5170 of 5802 is done
# 5171 of 5802 is done
# 5172 of 5802 is done
# 5173 of 5802 is done
# 5174 of 5802 is done
# 5175 of 5802 is done
# 5176 of 5802 is done
# 5177 of 5802 is done
# 5178 of 5802 is done
# 5179 of 5802 is done
# 5180 of 5802 is done
# 5181 of 5802 is done
# 5182 of 5802 is done
# 5183 of 5802 is done
# 5184 of 5802 is done
# 5185 of 5802 is done
# 5186 of 5802 is done
# 5187 of 5802 is done
# 5188 of 5802 is done
# 5189 of 5802 is done
# 5190 of 5802 is done
# 5191 of 5802 is done
# 5192 of 5802 is done
# 5193 of 5802 is done
# 5194 of 5802 is done
# 5195 of 5802 is done
# 5196 of 5802 is done
# 5197 of 5802 is done
# 5198 of 5802 is done
# 5199 of 5802 is done
# 5200 of 5802 is done
# 5201 of 5802 is done
# 5202 of 5802 is done
# 5203 of 5802 is done
# 5204 of 5802 is done
# 5205 of 5802 is done
# 5206 of 5802 is done
# 5207 of 5802 is done
# 5208 of 5802 is done
# 5209 of 5802 is done
# 5210 of 5802 is done
# 5211 of 5802 is done
# 5212 of 5802 is done
# 5213 of 5802 is done
# 5214 of 5802 is done
# 5215 of 5802 is done
# 5216 of 5802 is done
# 5217 of 5802 is done
# 5218 of 5802 is done
# 5219 of 5802 is done
# 5220 of 5802 is done
# 5221 of 5802 is done
# 5222 of 5802 is done
# 5223 of 5802 is done
# 5224 of 5802 is done
# 5225 of 5802 is done
# 5226 of 5802 is done
# 5227 of 5802 is done
# 5228 of 5802 is done
# 5229 of 5802 is done
# 5230 of 5802 is done
# 5231 of 5802 is done
# 5232 of 5802 is done
# 5233 of 5802 is done
# 5234 of 5802 is done
# 5235 of 5802 is done
# 5236 of 5802 is done
# 5237 of 5802 is done
# 5238 of 5802 is done
# 5239 of 5802 is done
# 5240 of 5802 is done
# 5241 of 5802 is done
# 5242 of 5802 is done
# 5243 of 5802 is done
# 5244 of 5802 is done
# 5245 of 5802 is done
# 5246 of 5802 is done
# 5247 of 5802 is done
# 5248 of 5802 is done
# 5249 of 5802 is done
# 5250 of 5802 is done
# 5251 of 5802 is done
# 5252 of 5802 is done
# 5253 of 5802 is done
# 5254 of 5802 is done
# 5255 of 5802 is done
# 5256 of 5802 is done
# 5257 of 5802 is done
# 5258 of 5802 is done
# 5259 of 5802 is done
# 5260 of 5802 is done
# 5261 of 5802 is done
# 5262 of 5802 is done
# 5263 of 5802 is done
# 5264 of 5802 is done
# 5265 of 5802 is done
# 5266 of 5802 is done
# 5267 of 5802 is done
# 5268 of 5802 is done
# 5269 of 5802 is done
# 5270 of 5802 is done
# 5271 of 5802 is done
# 5272
# 5273 of 5802 is done
# 5274 of 5802 is done
# 5275 of 5802 is done
# 5276 of 5802 is done
# 5277 of 5802 is done
# 5278 of 5802 is done
# 5279 of 5802 is done
# 5280 of 5802 is done
# 5281 of 5802 is done
# 5282 of 5802 is done
# 5283 of 5802 is done
# 5284 of 5802 is done
# 5285 of 5802 is done
# 5286 of 5802 is done
# 5287 of 5802 is done
# 5288 of 5802 is done
# 5289 of 5802 is done
# 5290 of 5802 is done
# 5291 of 5802 is done
# 5292 of 5802 is done
# 5293 of 5802 is done
# 5294 of 5802 is done
# 5295 of 5802 is done
# 5296 of 5802 is done
# 5297 of 5802 is done
# 5298 of 5802 is done
# 5299 of 5802 is done
# 5300 of 5802 is done
# 5301 of 5802 is done
# 5302 of 5802 is done
# 5303 of 5802 is done
# 5304 of 5802 is done
# 5305 of 5802 is done
# 5306 of 5802 is done
# 5307 of 5802 is done
# 5308 of 5802 is done
# 5309 of 5802 is done
# 5310 of 5802 is done
# 5311 of 5802 is done
# 5312 of 5802 is done
# 5313 of 5802 is done
# 5314 of 5802 is done
# 5315 of 5802 is done
# 5316 of 5802 is done
# 5317 of 5802 is done
# 5318 of 5802 is done
# 5319 of 5802 is done
# 5320 of 5802 is done
# 5321 of 5802 is done
# 5322 of 5802 is done
# 5323 of 5802 is done
# 5324 of 5802 is done
# 5325 of 5802 is done
# 5326 of 5802 is done
# 5327 of 5802 is done
# 5328 of 5802 is done
# 5329 of 5802 is done
# 5330 of 5802 is done
# 5331 of 5802 is done
# 5332 of 5802 is done
# 5333 of 5802 is done
# 5334 of 5802 is done
# 5335 of 5802 is done
# 5336 of 5802 is done
# 5337 of 5802 is done
# 5338 of 5802 is done
# 5339 of 5802 is done
# 5340 of 5802 is done
# 5341 of 5802 is done
# 5342 of 5802 is done
# 5343 of 5802 is done
# 5344 of 5802 is done
# 5345 of 5802 is done
# 5346 of 5802 is done
# 5347 of 5802 is done
# 5348 of 5802 is done
# 5349 of 5802 is done
# 5350 of 5802 is done
# 5351 of 5802 is done
# 5352 of 5802 is done
# 5353 of 5802 is done
# 5354 of 5802 is done
# 5355 of 5802 is done
# 5356 of 5802 is done
# 5357 of 5802 is done
# 5358 of 5802 is done
# 5359 of 5802 is done
# 5360 of 5802 is done
# 5361 of 5802 is done
# 5362 of 5802 is done
# 5363 of 5802 is done
# 5364 of 5802 is done
# 5365 of 5802 is done
# 5366 of 5802 is done
# 5367 of 5802 is done
# 5368 of 5802 is done
# 5369 of 5802 is done
# 5370 of 5802 is done
# 5371 of 5802 is done
# 5372 of 5802 is done
# 5373 of 5802 is done
# 5374 of 5802 is done
# 5375 of 5802 is done
# 5376 of 5802 is done
# 5377 of 5802 is done
# 5378 of 5802 is done
# 5379 of 5802 is done
# 5380 of 5802 is done
# 5381 of 5802 is done
# 5382 of 5802 is done
# 5383 of 5802 is done
# 5384 of 5802 is done
# 5385 of 5802 is done
# 5386 of 5802 is done
# 5387 of 5802 is done
# 5388 of 5802 is done
# 5389 of 5802 is done
# 5390 of 5802 is done
# 5391 of 5802 is done
# 5392 of 5802 is done
# 5393 of 5802 is done
# 5394 of 5802 is done
# 5395 of 5802 is done
# 5396 of 5802 is done
# 5397 of 5802 is done
# 5398 of 5802 is done
# 5399 of 5802 is done
# 5400 of 5802 is done
# 5401 of 5802 is done
# 5402 of 5802 is done
# 5403 of 5802 is done
# 5404 of 5802 is done
# 5405 of 5802 is done
# 5406 of 5802 is done
# 5407 of 5802 is done
# 5408 of 5802 is done
# 5409 of 5802 is done
# 5410 of 5802 is done
# 5411 of 5802 is done
# 5412 of 5802 is done
# 5413 of 5802 is done
# 5414 of 5802 is done
# 5415 of 5802 is done
# 5416 of 5802 is done
# 5417 of 5802 is done
# 5418 of 5802 is done
# 5419 of 5802 is done
# 5420 of 5802 is done
# 5421 of 5802 is done
# 5422 of 5802 is done
# 5423 of 5802 is done
# 5424 of 5802 is done
# 5425 of 5802 is done
# 5426 of 5802 is done
# 5427 of 5802 is done
# 5428 of 5802 is done
# 5429 of 5802 is done
# 5430 of 5802 is done
# 5431 of 5802 is done
# 5432 of 5802 is done
# 5433 of 5802 is done
# 5434 of 5802 is done
# 5435 of 5802 is done
# 5436 of 5802 is done
# 5437 of 5802 is done
# 5438 of 5802 is done
# 5439 of 5802 is done
# 5440 of 5802 is done
# 5441 of 5802 is done
# 5442 of 5802 is done
# 5443 of 5802 is done
# 5444 of 5802 is done
# 5445 of 5802 is done
# 5446 of 5802 is done
# 5447 of 5802 is done
# 5448 of 5802 is done
# 5449 of 5802 is done
# 5450 of 5802 is done
# 5451 of 5802 is done
# 5452 of 5802 is done
# 5453 of 5802 is done
# 5454 of 5802 is done
# 5455 of 5802 is done
# 5456 of 5802 is done
# 5457 of 5802 is done
# 5458 of 5802 is done
# 5459 of 5802 is done
# 5460 of 5802 is done
# 5461 of 5802 is done
# 5462 of 5802 is done
# 5463 of 5802 is done
# 5464 of 5802 is done
# 5465 of 5802 is done
# 5466 of 5802 is done
# 5467 of 5802 is done
# 5468 of 5802 is done
# 5469 of 5802 is done
# 5470 of 5802 is done
# 5471 of 5802 is done
# 5472 of 5802 is done
# 5473 of 5802 is done
# 5474 of 5802 is done
# 5475 of 5802 is done
# 5476 of 5802 is done
# 5477 of 5802 is done
# 5478 of 5802 is done
# 5479 of 5802 is done
# 5480 of 5802 is done
# 5481 of 5802 is done
# 5482 of 5802 is done
# 5483 of 5802 is done
# 5484 of 5802 is done
# 5485 of 5802 is done
# 5486 of 5802 is done
# 5487 of 5802 is done
# 5488 of 5802 is done
# 5489 of 5802 is done
# 5490 of 5802 is done
# 5491 of 5802 is done
# 5492 of 5802 is done
# 5493 of 5802 is done
# 5494 of 5802 is done
# 5495 of 5802 is done
# 5496 of 5802 is done
# 5497 of 5802 is done
# 5498 of 5802 is done
# 5499 of 5802 is done
# 5500 of 5802 is done
# 5501 of 5802 is done
# 5502 of 5802 is done
# 5503 of 5802 is done
# 5504 of 5802 is done
# 5505 of 5802 is done
# 5506 of 5802 is done
# 5507 of 5802 is done
# 5508 of 5802 is done
# 5509 of 5802 is done
# 5510 of 5802 is done
# 5511 of 5802 is done
# 5512 of 5802 is done
# 5513 of 5802 is done
# 5514 of 5802 is done
# 5515 of 5802 is done
# 5516 of 5802 is done
# 5517 of 5802 is done
# 5518 of 5802 is done
# 5519 of 5802 is done
# 5520 of 5802 is done
# 5521 of 5802 is done
# 5522 of 5802 is done
# 5523 of 5802 is done
# 5524 of 5802 is done
# 5525 of 5802 is done
# 5526 of 5802 is done
# 5527 of 5802 is done
# 5528 of 5802 is done
# 5529 of 5802 is done
# 5530 of 5802 is done
# 5531 of 5802 is done
# 5532 of 5802 is done
# 5533 of 5802 is done
# 5534 of 5802 is done
# 5535 of 5802 is done
# 5536 of 5802 is done
# 5537 of 5802 is done
# 5538 of 5802 is done
# 5539 of 5802 is done
# 5540 of 5802 is done
# 5541 of 5802 is done
# 5542 of 5802 is done
# 5543 of 5802 is done
# 5544 of 5802 is done
# 5545 of 5802 is done
# 5546 of 5802 is done
# 5547 of 5802 is done
# 5548 of 5802 is done
# 5549 of 5802 is done
# 5550 of 5802 is done
# 5551 of 5802 is done
# 5552 of 5802 is done
# 5553 of 5802 is done
# 5554 of 5802 is done
# 5555 of 5802 is done
# 5556 of 5802 is done
# 5557 of 5802 is done
# 5558 of 5802 is done
# 5559 of 5802 is done
# 5560 of 5802 is done
# 5561 of 5802 is done
# 5562 of 5802 is done
# 5563 of 5802 is done
# 5564 of 5802 is done
# 5565 of 5802 is done
# 5566 of 5802 is done
# 5567 of 5802 is done
# 5568 of 5802 is done
# 5569 of 5802 is done
# 5570 of 5802 is done
# 5571 of 5802 is done
# 5572 of 5802 is done
# 5573 of 5802 is done
# 5574 of 5802 is done
# 5575 of 5802 is done
# 5576 of 5802 is done
# 5577 of 5802 is done
# 5578 of 5802 is done
# 5579 of 5802 is done
# 5580 of 5802 is done
# 5581 of 5802 is done
# 5582 of 5802 is done
# 5583 of 5802 is done
# 5584 of 5802 is done
# 5585 of 5802 is done
# 5586 of 5802 is done
# 5587 of 5802 is done
# 5588 of 5802 is done
# 5589 of 5802 is done
# 5590 of 5802 is done
# 5591 of 5802 is done
# 5592 of 5802 is done
# 5593 of 5802 is done
# 5594 of 5802 is done
# 5595 of 5802 is done
# 5596 of 5802 is done
# 5597 of 5802 is done
# 5598 of 5802 is done
# 5599 of 5802 is done
# 5600 of 5802 is done
# 5601 of 5802 is done
# 5602 of 5802 is done
# 5603 of 5802 is done
# 5604 of 5802 is done
# 5605 of 5802 is done
# 5606 of 5802 is done
# 5607 of 5802 is done
# 5608 of 5802 is done
# 5609 of 5802 is done
# 5610 of 5802 is done
# 5611 of 5802 is done
# 5612 of 5802 is done
# 5613 of 5802 is done
# 5614 of 5802 is done
# 5615 of 5802 is done
# 5616 of 5802 is done
# 5617 of 5802 is done
# 5618 of 5802 is done
# 5619 of 5802 is done
# 5620 of 5802 is done
# 5621 of 5802 is done
# 5622 of 5802 is done
# 5623 of 5802 is done
# 5624 of 5802 is done
# 5625 of 5802 is done
# 5626 of 5802 is done
# 5627 of 5802 is done
# 5628
# 5629 of 5802 is done
# 5630 of 5802 is done
# 5631 of 5802 is done
# 5632 of 5802 is done
# 5633 of 5802 is done
# 5634 of 5802 is done
# 5635 of 5802 is done
# 5636 of 5802 is done
# 5637 of 5802 is done
# 5638 of 5802 is done
# 5639 of 5802 is done
# 5640 of 5802 is done
# 5641 of 5802 is done
# 5642 of 5802 is done
# 5643 of 5802 is done
# 5644 of 5802 is done
# 5645 of 5802 is done
# 5646 of 5802 is done
# 5647 of 5802 is done
# 5648 of 5802 is done
# 5649 of 5802 is done
# 5650 of 5802 is done
# 5651 of 5802 is done
# 5652 of 5802 is done
# 5653 of 5802 is done
# 5654 of 5802 is done
# 5655 of 5802 is done
# 5656 of 5802 is done
# 5657 of 5802 is done
# 5658 of 5802 is done
# 5659 of 5802 is done
# 5660 of 5802 is done
# 5661 of 5802 is done
# 5662 of 5802 is done
# 5663 of 5802 is done
# 5664 of 5802 is done
# 5665 of 5802 is done
# 5666 of 5802 is done
# 5667 of 5802 is done
# 5668 of 5802 is done
# 5669 of 5802 is done
# 5670 of 5802 is done
# 5671 of 5802 is done
# 5672 of 5802 is done
# 5673 of 5802 is done
# 5674 of 5802 is done
# 5675 of 5802 is done
# 5676 of 5802 is done
# 5677 of 5802 is done
# 5678 of 5802 is done
# 5679 of 5802 is done
# 5680 of 5802 is done
# 5681 of 5802 is done
# 5682 of 5802 is done
# 5683 of 5802 is done
# 5684 of 5802 is done
# 5685 of 5802 is done
# 5686 of 5802 is done
# 5687 of 5802 is done
# 5688 of 5802 is done
# 5689 of 5802 is done
# 5690 of 5802 is done
# 5691 of 5802 is done
# 5692 of 5802 is done
# 5693 of 5802 is done
# 5694 of 5802 is done
# 5695 of 5802 is done
# 5696 of 5802 is done
# 5697 of 5802 is done
# 5698 of 5802 is done
# 5699 of 5802 is done
# 5700 of 5802 is done
# 5701 of 5802 is done
# 5702 of 5802 is done
# 5703 of 5802 is done
# 5704 of 5802 is done
# 5705 of 5802 is done
# 5706 of 5802 is done
# 5707 of 5802 is done
# 5708 of 5802 is done
# 5709 of 5802 is done
# 5710 of 5802 is done
# 5711 of 5802 is done
# 5712 of 5802 is done
# 5713 of 5802 is done
# 5714 of 5802 is done
# 5715 of 5802 is done
# 5716 of 5802 is done
# 5717 of 5802 is done
# 5718 of 5802 is done
# 5719 of 5802 is done
# 5720 of 5802 is done
# 5721 of 5802 is done
# 5722 of 5802 is done
# 5723 of 5802 is done
# 5724 of 5802 is done
# 5725 of 5802 is done
# 5726 of 5802 is done
# 5727 of 5802 is done
# 5728 of 5802 is done
# 5729 of 5802 is done
# 5730 of 5802 is done
# 5731 of 5802 is done
# 5732 of 5802 is done
# 5733 of 5802 is done
# 5734 of 5802 is done
# 5735 of 5802 is done
# 5736 of 5802 is done
# 5737 of 5802 is done
# 5738 of 5802 is done
# 5739 of 5802 is done
# 5740 of 5802 is done
# 5741 of 5802 is done
# 5742 of 5802 is done
# 5743 of 5802 is done
# 5744 of 5802 is done
# 5745 of 5802 is done
# 5746 of 5802 is done
# 5747 of 5802 is done
# 5748 of 5802 is done
# 5749 of 5802 is done
# 5750 of 5802 is done
# 5751 of 5802 is done
# 5752 of 5802 is done
# 5753 of 5802 is done
# 5754 of 5802 is done
# 5755 of 5802 is done
# 5756 of 5802 is done
# 5757 of 5802 is done
# 5758 of 5802 is done
# 5759 of 5802 is done
# 5760 of 5802 is done
# 5761 of 5802 is done
# 5762 of 5802 is done
# 5763 of 5802 is done
# 5764 of 5802 is done
# 5765 of 5802 is done
# 5766 of 5802 is done
# 5767 of 5802 is done
# 5768 of 5802 is done
# 5769 of 5802 is done
# 5770 of 5802 is done
# 5771 of 5802 is done
# 5772 of 5802 is done
# 5773 of 5802 is done
# 5774 of 5802 is done
# 5775 of 5802 is done
# 5776 of 5802 is done
# 5777 of 5802 is done
# 5778 of 5802 is done
# 5779 of 5802 is done
# 5780 of 5802 is done
# 5781 of 5802 is done
# 5782 of 5802 is done
# 5783 of 5802 is done
# 5784 of 5802 is done
# 5785 of 5802 is done
# 5786 of 5802 is done
# 5787 of 5802 is done
# 5788 of 5802 is done
# 5789 of 5802 is done
# 5790 of 5802 is done
# 5791 of 5802 is done
# 5792 of 5802 is done
# 5793 of 5802 is done
# 5794 of 5802 is done
# 5795 of 5802 is done
# 5796 of 5802 is done
# 5797 of 5802 is done
# 5798 of 5802 is done
# 5799 of 5802 is done
# 5800 of 5802 is done
# 5801 of 5802 is done

# %%
final_df.shape
# Out:
# (1806467, 13)

# %%
final_df.head()
# Out:
#    CAPITL  CENTRL  DUNWOD  GENESE  HUD VL  LONGIL  MHK VL  MILLWD  N.Y.C.  \
# 0   985.0  1461.0   443.0   830.0   970.0     NaN   623.0   166.0     NaN
# 1   995.0  1455.0   455.0   818.0   990.0     NaN   614.0   150.0     NaN
# 2   980.0  1447.0   441.0   816.0   980.0     NaN   605.0   158.0     NaN
# 3   947.0  1417.0   431.0   800.0   962.0     NaN   611.0   153.0     NaN
# 4   946.0  1429.0   439.0   798.0   969.0     NaN   610.0   148.0     NaN
#
#    N.Y.C._LONGIL  NORTH           Time Stamp    WEST
# 0         6217.0  659.0  05/26/2001 00:00:00  1505.0
# 1         6174.0  636.0  05/26/2001 00:00:50  1474.0
# 2         6158.0  649.0  05/26/2001 00:05:20  1484.0
# 3         6140.0  646.0  05/26/2001 00:06:50  1515.0
# 4         6100.0  647.0  05/26/2001 00:11:50  1465.0

# %% [markdown]
# # Standardise column names and save the data

# %%
new_col_names = []
for i in final_df.columns.values:
    temp = i.lower()
    temp = temp.replace(".", "")
    temp = temp.replace(" ", "_")
    new_col_names.append(temp)

# %%
new_col_names
# Out:
# ['capitl',
#  'centrl',
#  'dunwod',
#  'genese',
#  'hud_vl',
#  'longil',
#  'mhk_vl',
#  'millwd',
#  'nyc',
#  'nyc_longil',
#  'north',
#  'time_stamp',
#  'west']

# %%
final_df.columns = new_col_names

# %%
store = pd.HDFStore('store.h5')
store.append('full_data_jun_14', final_df, data_columns=True)

# %% [markdown]
# # Reading from the pytable

# %%
df = pd.read_hdf('store.h5', 'full_data_jun_14')

# %%
df.head()
# Out:
#    capitl  centrl  dunwod  genese  hud_vl  longil  mhk_vl  millwd  nyc  \
# 0   985.0  1461.0   443.0   830.0   970.0     NaN   623.0   166.0  NaN
# 1   995.0  1455.0   455.0   818.0   990.0     NaN   614.0   150.0  NaN
# 2   980.0  1447.0   441.0   816.0   980.0     NaN   605.0   158.0  NaN
# 3   947.0  1417.0   431.0   800.0   962.0     NaN   611.0   153.0  NaN
# 4   946.0  1429.0   439.0   798.0   969.0     NaN   610.0   148.0  NaN
#
#    nyc_longil  north           time_stamp    west
# 0      6217.0  659.0  05/26/2001 00:00:00  1505.0
# 1      6174.0  636.0  05/26/2001 00:00:50  1474.0
# 2      6158.0  649.0  05/26/2001 00:05:20  1484.0
# 3      6140.0  646.0  05/26/2001 00:06:50  1515.0
# 4      6100.0  647.0  05/26/2001 00:11:50  1465.0

# %% [markdown]
# # Checking the number of NaNs in each column

# %%
df.isnull().sum()
# Out:
# capitl             47
# centrl             49
# dunwod             49
# genese             49
# hud_vl             47
# longil         517019
# mhk_vl             48
# millwd             48
# nyc            517020
# nyc_longil    1289495
# north              47
# time_stamp          0
# west               48
# dtype: int64

# %% [markdown]
# # Removing the columns with large number of  missing values
#
# - nyc
# - nyc_longil
# - longil

# %%
needed_columns = ['time_stamp', 'capitl', 'centrl', 'dunwod', 'genese', 'hud_vl', 'mhk_vl', 'millwd', 'north', 'west']
df_new = df[needed_columns]

# %%
df_new.head()
# Out:
#             time_stamp  capitl  centrl  dunwod  genese  hud_vl  mhk_vl  \
# 0  05/26/2001 00:00:00   985.0  1461.0   443.0   830.0   970.0   623.0
# 1  05/26/2001 00:00:50   995.0  1455.0   455.0   818.0   990.0   614.0
# 2  05/26/2001 00:05:20   980.0  1447.0   441.0   816.0   980.0   605.0
# 3  05/26/2001 00:06:50   947.0  1417.0   431.0   800.0   962.0   611.0
# 4  05/26/2001 00:11:50   946.0  1429.0   439.0   798.0   969.0   610.0
#
#    millwd  north    west
# 0   166.0  659.0  1505.0
# 1   150.0  636.0  1474.0
# 2   158.0  649.0  1484.0
# 3   153.0  646.0  1515.0
# 4   148.0  647.0  1465.0

# %% [markdown]
# # Removing the rows with missing values

# %%
df_new[df_new.isnull().any(axis=1)]
# Out:
#                   time_stamp  capitl  centrl  dunwod  genese  hud_vl  mhk_vl  \
# 520738   02/12/2005 21:55:00     NaN     NaN     NaN     NaN     NaN     NaN
# 521045   02/13/2005 23:10:00     NaN     NaN     NaN     NaN     NaN     NaN
# 521890   02/16/2005 21:00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 547302   05/18/2005 12:20:00     NaN     NaN     NaN     NaN     NaN     NaN
# 547345   05/18/2005 15:55:00     NaN     NaN     NaN     NaN     NaN     NaN
# 552332   06/04/2005 22:30:00     NaN     NaN     NaN     NaN     NaN     NaN
# 552827   06/06/2005 15:35:00     NaN     NaN     NaN     NaN     NaN     NaN
# 553370   06/08/2005 12:45:00     NaN     NaN     NaN     NaN     NaN     NaN
# 562981   07/12/2005 12:15:00     NaN     NaN     NaN     NaN     NaN     NaN
# 562982   07/12/2005 12:20:00     NaN     NaN     NaN     NaN     NaN     NaN
# 562983   07/12/2005 12:25:00     NaN     NaN     NaN     NaN     NaN     NaN
# 573205   08/16/2005 11:30:00     NaN     NaN     NaN     NaN     NaN     NaN
# 600000   11/17/2005 08:35:00     NaN     NaN     NaN     NaN     NaN     NaN
# 600001   11/17/2005 08:40:00     NaN     NaN     NaN     NaN     NaN     NaN
# 600002   11/17/2005 08:45:00     NaN     NaN     NaN     NaN     NaN     NaN
# 600003   11/17/2005 08:50:00     NaN     NaN     NaN     NaN     NaN     NaN
# 600004   11/17/2005 08:55:00     NaN     NaN     NaN     NaN     NaN     NaN
# 600005   11/17/2005 09:00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 600006   11/17/2005 09:05:00     NaN     NaN     NaN     NaN     NaN     NaN
# 600007   11/17/2005 09:10:00     NaN     NaN     NaN     NaN     NaN     NaN
# 600008   11/17/2005 09:15:00     NaN     NaN     NaN     NaN     NaN     NaN
# 600009   11/17/2005 09:20:00     NaN     NaN     NaN     NaN     NaN     NaN
# 600010   11/17/2005 09:25:00     NaN     NaN     NaN     NaN     NaN     NaN
# 629695   02/27/2006 08:30:00     NaN     NaN     NaN     NaN     NaN     NaN
# 706291   11/17/2006 23:59:51     NaN     NaN     NaN     NaN     NaN     NaN
# 809998   11/11/2007 11:03:46  1337.5  1791.6     NaN  1058.2  1190.4   875.9
# 873478   06/17/2008 23:59:56     NaN     NaN     NaN     NaN     NaN     NaN
# 990437   07/28/2009 16:40:00  1904.1  2507.5  1143.5     NaN  1851.8  1222.7
# 1194338  07/07/2011 04:16:05     NaN     NaN     NaN     NaN     NaN     NaN
# 1194396  07/07/2011 08:50:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1194944  07/09/2011 05:35:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1195447  07/10/2011 23:20:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1274596  04/09/2012 15:22:34  1374.8     NaN   638.0  1132.9  1009.5   949.1
# 1278333  04/22/2012 12:03:27  1286.5  1761.6     NaN  1028.6   999.6   868.2
# 1289976  06/01/2012 13:30:00  1458.3  1924.9   824.3  1191.8  1335.9   936.6
# 1338239  11/14/2012 18:05:00  1565.7  2166.3   748.0     NaN  1304.2  1050.3
# 1358443  01/22/2013 22:13:39  1581.3  2333.2   816.4  1355.1  1329.6     NaN
# 1406160  07/05/2013 03:10:00  1285.5  1619.5   743.7   932.7  1158.3   795.8
# 1442806  11/08/2013 18:04:40  1532.9     NaN   806.4  1304.8  1302.6  1101.5
# 1445539  11/17/2013 23:55:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1524737  08/15/2014 23:50:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1524738  08/15/2014 23:55:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1623252  07/20/2015 23:55:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1629630  08/11/2015 23:55:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1643869  09/29/2015 23:55:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1678700  01/28/2016 22:50:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1678701  01/28/2016 22:55:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1678702  01/28/2016 23:00:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1678703  01/28/2016 23:05:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1678706  01/28/2016 23:20:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1679581  01/31/2016 23:55:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1715640  06/18/2016 23:55:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1726107  07/24/2016 23:55:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1754870  10/31/2016 23:55:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1806465  05/22/2017 13:35:00     NaN     NaN     NaN     NaN     NaN     NaN
# 1806466  05/22/2017 13:40:00     NaN     NaN     NaN     NaN     NaN     NaN
#
#          millwd  north    west
# 520738      NaN    NaN     NaN
# 521045      NaN    NaN     NaN
# 521890      NaN    NaN     NaN
# 547302      NaN    NaN     NaN
# 547345      NaN    NaN     NaN
# 552332      NaN    NaN     NaN
# 552827      NaN    NaN     NaN
# 553370      NaN    NaN     NaN
# 562981      NaN    NaN     NaN
# 562982      NaN    NaN     NaN
# 562983      NaN    NaN     NaN
# 573205      NaN    NaN     NaN
# 600000      NaN    NaN     NaN
# 600001      NaN    NaN     NaN
# 600002      NaN    NaN     NaN
# 600003      NaN    NaN     NaN
# 600004      NaN    NaN     NaN
# 600005      NaN    NaN     NaN
# 600006      NaN    NaN     NaN
# 600007      NaN    NaN     NaN
# 600008      NaN    NaN     NaN
# 600009      NaN    NaN     NaN
# 600010      NaN    NaN     NaN
# 629695      NaN    NaN     NaN
# 706291      NaN    NaN     NaN
# 809998    292.0  787.4  1680.8
# 873478      NaN    NaN     NaN
# 990437    544.2  504.2  2195.3
# 1194338     NaN    NaN     NaN
# 1194396     NaN    NaN     NaN
# 1194944     NaN    NaN     NaN
# 1195447     NaN    NaN     NaN
# 1274596   324.9  750.1  1840.1
# 1278333   293.0  745.5  1690.1
# 1289976   376.8  719.2     NaN
# 1338239   411.3  824.5  2147.4
# 1358443   414.7  883.0  2163.5
# 1406160     NaN  654.2  1522.8
# 1442806   406.2  731.3  2019.6
# 1445539     NaN    NaN     NaN
# 1524737     NaN    NaN     NaN
# 1524738     NaN    NaN     NaN
# 1623252     NaN    NaN     NaN
# 1629630     NaN    NaN     NaN
# 1643869     NaN    NaN     NaN
# 1678700     NaN    NaN     NaN
# 1678701     NaN    NaN     NaN
# 1678702     NaN    NaN     NaN
# 1678703     NaN    NaN     NaN
# 1678706     NaN    NaN     NaN
# 1679581     NaN    NaN     NaN
# 1715640     NaN    NaN     NaN
# 1726107     NaN    NaN     NaN
# 1754870     NaN    NaN     NaN
# 1806465     NaN    NaN     NaN
# 1806466     NaN    NaN     NaN

# %%
df_new_one = df_new.dropna(axis=0, how="any")

# %%
print(df_new.shape)
print(df_new_one.shape)
# Out:
# (1806467, 10)
# (1806411, 10)

# %%
df_new_one.head()
# Out:
#             time_stamp  capitl  centrl  dunwod  genese  hud_vl  mhk_vl  \
# 0  05/26/2001 00:00:00   985.0  1461.0   443.0   830.0   970.0   623.0
# 1  05/26/2001 00:00:50   995.0  1455.0   455.0   818.0   990.0   614.0
# 2  05/26/2001 00:05:20   980.0  1447.0   441.0   816.0   980.0   605.0
# 3  05/26/2001 00:06:50   947.0  1417.0   431.0   800.0   962.0   611.0
# 4  05/26/2001 00:11:50   946.0  1429.0   439.0   798.0   969.0   610.0
#
#    millwd  north    west
# 0   166.0  659.0  1505.0
# 1   150.0  636.0  1474.0
# 2   158.0  649.0  1484.0
# 3   153.0  646.0  1515.0
# 4   148.0  647.0  1465.0

# %% [markdown]
# # Add another column depicts total load of NewYork

# %%
df_temp = df_new_one[['capitl', 'centrl', 'dunwod', 'genese', 'hud_vl', 'mhk_vl', 'millwd', 'north', 'west']]
df_new_one["total_ny_load"] = df_temp.sum(axis=1)
# Out:
# C:\Users\sleeba\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
df_new_one.head()
# Out:
#             time_stamp  capitl  centrl  dunwod  genese  hud_vl  mhk_vl  \
# 0  05/26/2001 00:00:00   985.0  1461.0   443.0   830.0   970.0   623.0
# 1  05/26/2001 00:00:50   995.0  1455.0   455.0   818.0   990.0   614.0
# 2  05/26/2001 00:05:20   980.0  1447.0   441.0   816.0   980.0   605.0
# 3  05/26/2001 00:06:50   947.0  1417.0   431.0   800.0   962.0   611.0
# 4  05/26/2001 00:11:50   946.0  1429.0   439.0   798.0   969.0   610.0
#
#    millwd  north    west  total_ny_load
# 0   166.0  659.0  1505.0         7642.0
# 1   150.0  636.0  1474.0         7587.0
# 2   158.0  649.0  1484.0         7560.0
# 3   153.0  646.0  1515.0         7482.0
# 4   148.0  647.0  1465.0         7451.0

# %%
store = pd.HDFStore('store.h5')
store.append('cleaned_data_jun_14', df_new_one, data_columns=True)

# %% [markdown]
# # TIME SERIES

# %%
import pandas as pd

# %%
data = pd.read_hdf('store.h5', 'cleaned_data_jun_14')

# %%
data.head()
# Out:
#             time_stamp  capitl  centrl  dunwod  genese  hud_vl  mhk_vl  \
# 0  05/26/2001 00:00:00   985.0  1461.0   443.0   830.0   970.0   623.0
# 1  05/26/2001 00:00:50   995.0  1455.0   455.0   818.0   990.0   614.0
# 2  05/26/2001 00:05:20   980.0  1447.0   441.0   816.0   980.0   605.0
# 3  05/26/2001 00:06:50   947.0  1417.0   431.0   800.0   962.0   611.0
# 4  05/26/2001 00:11:50   946.0  1429.0   439.0   798.0   969.0   610.0
#
#    millwd  north    west  total_ny_load
# 0   166.0  659.0  1505.0         7642.0
# 1   150.0  636.0  1474.0         7587.0
# 2   158.0  649.0  1484.0         7560.0
# 3   153.0  646.0  1515.0         7482.0
# 4   148.0  647.0  1465.0         7451.0

# %% [markdown]
# # Converting `time_stamp` to a `datetime` object and setting it as index

# %%
data['time_stamp'] = pd.to_datetime(data['time_stamp'], format='%m/%d/%Y %H:%M:%S')

# %%
data = data.set_index('time_stamp')

# %%
data.head()
# Out:
#                      capitl  centrl  dunwod  genese  hud_vl  mhk_vl  millwd  \
# time_stamp
# 2001-05-26 00:00:00   985.0  1461.0   443.0   830.0   970.0   623.0   166.0
# 2001-05-26 00:00:50   995.0  1455.0   455.0   818.0   990.0   614.0   150.0
# 2001-05-26 00:05:20   980.0  1447.0   441.0   816.0   980.0   605.0   158.0
# 2001-05-26 00:06:50   947.0  1417.0   431.0   800.0   962.0   611.0   153.0
# 2001-05-26 00:11:50   946.0  1429.0   439.0   798.0   969.0   610.0   148.0
#
#                      north    west  total_ny_load
# time_stamp
# 2001-05-26 00:00:00  659.0  1505.0         7642.0
# 2001-05-26 00:00:50  636.0  1474.0         7587.0
# 2001-05-26 00:05:20  649.0  1484.0         7560.0
# 2001-05-26 00:06:50  646.0  1515.0         7482.0
# 2001-05-26 00:11:50  647.0  1465.0         7451.0

# %% [markdown]
# # Considering only `total_ny_load`

# %%
 data_total = data["total_ny_load"]

# %%
store = pd.HDFStore('store.h5')
store.append('cleaned_data_total_ny_jun_14', data_total, data_columns=True)

# %%
# store.get_node('cleaned_data__total_ny_jun_14')._f_rename('cleaned_data_total_ny_jun_14')

# %%
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: store.h5
# /cleaned_data_jun_14                     frame_table  (typ->appendable,nrows->3612822,ncols->11,indexers->[index],dc->[time_stamp,capitl,centrl,dunwod,genese,hud_vl,mhk_vl,millwd,north,west,total_ny_load])
# /cleaned_data_total_ny_jun_14            series_table (typ->appendable,nrows->3612822,ncols->1,indexers->[index],dc->[total_ny_load])
# /full_data_jun_14                        frame_table  (typ->appendable,nrows->1806467,ncols->13,indexers->[index],dc->[capitl,centrl,dunwod,genese,hud_vl,longil,mhk_vl,millwd,nyc,nyc_longil,north,time_stamp,west])

# %% [markdown]
# # ARIMA MODEL

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
data = pd.read_hdf('store.h5', 'cleaned_data_total_ny_jun_14')

# %%
data.tail()
# Out:
# time_stamp
# 2017-05-22 13:10:00    9641.4
# 2017-05-22 13:15:00    9583.7
# 2017-05-22 13:20:00    9591.9
# 2017-05-22 13:25:00    9618.3
# 2017-05-22 13:30:00    9579.0
# Name: total_ny_load, dtype: float64

# %%
plt.plot(data)

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = pd.rolling_mean(timeseries, window=12)
    rolstd = pd.rolling_std(timeseries, window=12)

    #Plot rolling statistics:
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value ({})'.format(key)] = value
    print(dfoutput)
# Out:
# C:\Users\sleeba\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
test_stationarity(data)
# Out:
# C:\Users\sleeba\Anaconda3\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=12).mean()
# C:\Users\sleeba\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=12).std()
