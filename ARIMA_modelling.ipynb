# %%
library(fpp )
library(repr)

# %%
options(repr.plot.width=15, repr.plot.height=6)

# %%
data  <- read.csv("for_R.csv", stringsAsFactors = FALSE, header = F)

# %%
data$V1 <- as.POSIXct(data$V1, format="%Y-%m-%d %H:%M:%S")

# %%
plot(data)
# Out:
# plot without title

# %%
adf.test(x, alternative = "stationary")

# %%
Acf(data, lag.max = NULL, plot = TRUE, na.action = na.contiguous, demean=TRUE)
# Out:
# Plot with title "V2"

# %%
Pacf(data, lag.max=NULL, plot=TRUE, na.action=na.contiguous)
# Out:
# Plot with title "V2"

# %%
library(forecast)

# %%
fit <- stl(log(data$V2))
plot(fit)
# Out:
# Error in stl(log(data$V2)): series is not periodic or has less than two periods
# Traceback:
#
# 1. stl(log(data$V2))
# 2. stop("series is not periodic or has less than two periods")
